# %%
from planning.football import football_model
from planning.search import breadth_first_tree_search
from planning.planning import ForwardPlan
from team import Team
from game import Football
from field import Field
from team import Team
zones = [
    "Defense Left",
    "Defense Center",
    "Defense Right",

    "Midfield Left",
    "Midfield Center",
    "Midfield Right",

    "Attack Left",
    "Attack Center",
    "Attack Right"
]
field = Field("f1", 3, 3, zones)

# %%
# x = game.play()

# %%
# for i in range(1):
#     game = Football(team1, team2, field, 45)
#     x = game.play()
#     match[x.team_name] += 1

# match

# %%
from multiprocessing import Process
from time import sleep
import pandas as pd

matches = [("portugal", "ghana"),('portugal', 'uruguay'),('portugal', 'south-korea'),('ghana', "uruguay"),('ghana', "south-korea"),("uruguay", "south-korea")]
df = pd.DataFrame(columns=['Team1', 'Team2','Wins1', "Wins2"])

for t1,t2 in matches:
    team1 = Team(t2, field.field)
    team2 = Team(t1, field.field)


    Pros = []
    match = {
        team1.team_name: 0,
        team2.team_name: 0
    }

    def function_x():
        game = Football(team1, team2, field, 90)
        x = game.play()
        if x is not None:
            match[x.team_name] += 1
     

    for i in range(10):
        function_x()
    
    df.append({'Team1': team1.team_name, 'Team2': team2.team_name, 'Wins1': match[team1.team_name], 'Wins2': match[team2.team_name]}, ignore_index=True)
    print(df)
# Out:
# Start Game
# Initialization Complete
# Player Jordan-ayew is shooting
# Jordan-ayew Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Pepe now has the ball
# Player Pepe is shooting
# Pepe Goooooooalll
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Pepe now has the ball
# Player Pepe is shooting
# Wollacott now has the ball
# ghana  now has the ball
# Alexander-djiku now has the ball
# Player Alexander-djiku is shooting
# Alexander-djiku Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Wollacott now has the ball
# ghana  now has the ball
# Alexander-djiku now has the ball
# Player Alexander-djiku is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# Pepe now has the ball
# Bruno-fernandes now has the ball
# Pepe now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213]
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Pepe now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-baba-rahman now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Ruben-dias now has the ball
# portugal  now has the ball
# William-carvalho now has the ball
# Ruben-dias now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-samed-salis now has the ball
# ghana  now has the ball
# Daniel-amartey now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Raphael-guerreiro now has the ball
# portugal  now has the ball
# Ruben-neves now has the ball
# Joao-cancelo now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-baba-rahman now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Joao-cancelo now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Daniel-amartey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Denis-odoi now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Pepe now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# Pepe now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Daniel-amartey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Joao-cancelo now has the ball
# portugal  now has the ball
# Ruben-neves now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Ruben-neves now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# [0.23654400000000003, 0.13728, 0.182642, 0.163371, 0.26923199999999997, 0.14651]
# Abdul-samed-salis now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Joao-cancelo now has the ball
# portugal  now has the ball
# Ruben-neves now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# William-carvalho now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Denis-odoi now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Joao-cancelo now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Jordan-ayew Goooooooalll
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Raphael-guerreiro now has the ball
# portugal  now has the ball
# Ruben-neves now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Alexander-djiku Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Mohammed-kudus Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Ruben-dias now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-baba-rahman now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Afena-Gyan Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Afena-Gyan Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Game Over
# Team portugal win [8, 16]
# Start Game
# Initialization Complete
# Player Jordan-ayew is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Jordan-ayew Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Mohammed-kudus Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Mohammed-kudus Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Wollacott now has the ball
# ghana  now has the ball
# Alexander-djiku now has the ball
# Player Alexander-djiku is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213]
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-samed-salis now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Ruben-neves now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Pepe now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# Denis-odoi now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Ruben-dias now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Ruben-neves now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Jordan-ayew Goooooooalll
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Wollacott now has the ball
# ghana  now has the ball
# Alexander-djiku now has the ball
# Player Alexander-djiku is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213]
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Mohammed-kudus Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Ruben-dias now has the ball
# portugal  now has the ball
# William-carvalho now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Ruben-dias now has the ball
# portugal  now has the ball
# William-carvalho now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Daniel-amartey now has the ball
# ghana  now has the ball
# Abdul-samed-salis now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# William-carvalho now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Alexander-djiku Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Mohammed-kudus Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Wollacott now has the ball
# ghana  now has the ball
# Alexander-djiku now has the ball
# Player Alexander-djiku is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213]
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Mohammed-kudus Goooooooalll
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Wollacott now has the ball
# ghana  now has the ball
# Alexander-djiku now has the ball
# Player Alexander-djiku is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# Pepe now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213]
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Mohammed-kudus Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Pepe now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Raphael-guerreiro now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# Denis-odoi now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Pepe now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# Pepe now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-samed-salis now has the ball
# ghana  now has the ball
# Daniel-amartey now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# William-carvalho now has the ball
# portugal  now has the ball
# Ruben-dias now has the ball
# William-carvalho now has the ball
# Ruben-dias now has the ball
# William-carvalho now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# Denis-odoi now has the ball
# Thomas-partey now has the ball
# Game Over
# Team ghana win [12, 10]
# Start Game
# Initialization Complete
# Player Mohammed-kudus is shooting
# Mohammed-kudus Goooooooalll
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Ruben-dias now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Alexander-djiku Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Denis-odoi now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Denis-odoi now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Pepe now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Joao-cancelo now has the ball
# portugal  now has the ball
# Ruben-neves now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Alexander-djiku Goooooooalll
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Afena-Gyan Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Thomas-partey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bruno-fernandes now has the ball
# portugal  now has the ball
# Pepe now has the ball
# Bruno-fernandes now has the ball
# Pepe now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# Pepe now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-baba-rahman now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Pepe now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Jordan-ayew Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Jordan-ayew Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Mohammed-kudus Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Denis-odoi now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Pepe now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# Denis-odoi now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# William-carvalho now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Ruben-neves now has the ball
# portugal  now has the ball
# Joao-cancelo now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Daniel-amartey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Pepe now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Joao-cancelo now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-baba-rahman now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Joao-cancelo now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# Denis-odoi now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Joao-cancelo now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Denis-odoi now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# Pepe now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Wollacott now has the ball
# ghana  now has the ball
# [0.308736, 0.1716, 0.142296, 0.38849999999999996, 0.294294, 0.24674999999999994, 0.15972000000000003]
# Ruben-neves now has the ball
# portugal  now has the ball
# Joao-cancelo now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Denis-odoi now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bruno-fernandes now has the ball
# portugal  now has the ball
# Pepe now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-baba-rahman now has the ball
# ghana  now has the ball
# Game Over
# Team portugal win [9, 10]
# Start Game
# Initialization Complete
# Player Cristiano-ronaldo is shooting
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# William-carvalho now has the ball
# portugal  now has the ball
# Ruben-dias now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Bruno-fernandes now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-samed-salis now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Pepe now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# Pepe now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Abdul-samed-salis now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Pepe now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Mohammed-kudus Goooooooalll
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Abdul-samed-salis now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Pepe now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# William-carvalho now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-baba-rahman now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Abdul-baba-rahman now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Pepe now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Denis-odoi now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Afena-Gyan Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# Pepe now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-samed-salis now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Mohammed-kudus Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Denis-odoi now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Mohammed-kudus Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Ruben-neves now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# William-carvalho now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Joao-cancelo now has the ball
# portugal  now has the ball
# Ruben-neves now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# William-carvalho now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-samed-salis now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Pepe now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# [0.23654400000000003, 0.13728, 0.182642, 0.163371, 0.26923199999999997, 0.14651]
# Daniel-amartey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Denis-odoi now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# William-carvalho now has the ball
# portugal  now has the ball
# Ruben-dias now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Ruben-dias now has the ball
# portugal  now has the ball
# Game Over
# Team portugal win [7, 11]
# Start Game
# Initialization Complete
# Player Bernardo-silva is shooting
# Daniel-amartey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Pepe now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# Pepe now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-samed-salis now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# William-carvalho now has the ball
# portugal  now has the ball
# Ruben-dias now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Afena-Gyan Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# Denis-odoi now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Joao-cancelo now has the ball
# portugal  now has the ball
# Ruben-neves now has the ball
# Joao-cancelo now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Jordan-ayew Goooooooalll
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Wollacott now has the ball
# ghana  now has the ball
# Alexander-djiku now has the ball
# Player Alexander-djiku is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# Pepe now has the ball
# Bruno-fernandes now has the ball
# Pepe now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213]
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Mohammed-kudus Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Mohammed-kudus Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Denis-odoi now has the ball
# ghana  now has the ball
# Thomas-partey now has the ball
# Denis-odoi now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Raphael-guerreiro now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Jordan-ayew Goooooooalll
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Denis-odoi now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# William-carvalho now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# ...
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-baba-rahman now has the ball
# ghana  now has the ball
# Thomas-partey now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Raphael-guerreiro now has the ball
# portugal  now has the ball
# Game Over
# Team portugal win [7, 8]
# Start Game
# Initialization Complete
# Player Jordan-ayew is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Ruben-neves now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-samed-salis now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Raphael-guerreiro now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Ruben-dias now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Denis-odoi now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bruno-fernandes now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Ruben-neves now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bruno-fernandes now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# Denis-odoi now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Pepe now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# Denis-odoi now has the ball
# Thomas-partey now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Ruben-dias now has the ball
# portugal  now has the ball
# William-carvalho now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Ruben-dias now has the ball
# portugal  now has the ball
# William-carvalho now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Daniel-amartey now has the ball
# ghana  now has the ball
# Abdul-samed-salis now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Joao-cancelo now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Daniel-amartey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Pepe now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Alexander-djiku Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Ruben-neves now has the ball
# portugal  now has the ball
# Joao-cancelo now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Ruben-neves now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# William-carvalho now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Thomas-partey now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Jordan-ayew Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Wollacott now has the ball
# ghana  now has the ball
# [0.308736, 0.1716, 0.142296, 0.38849999999999996, 0.294294, 0.24674999999999994, 0.15972000000000003]
# Ruben-dias now has the ball
# portugal  now has the ball
# William-carvalho now has the ball
# Ruben-dias now has the ball
# William-carvalho now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Pepe now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Alexander-djiku now has the ball
# ghana  now has the ball
# Player Alexander-djiku is shooting
# Ruben-dias now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Denis-odoi now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Joao-cancelo now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Denis-odoi now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Ruben-neves now has the ball
# portugal  now has the ball
# Joao-cancelo now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Rafael-leao Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# Pepe now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Jordan-ayew now has the ball
# ghana  now has the ball
# Player Jordan-ayew is shooting
# Ruben-dias now has the ball
# portugal  now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213, 0.392, 0.264, 0.30150000000000005, 0.3124, 0.36340000000000006, 0.28600000000000003]
# Abdul-samed-salis now has the ball
# ghana  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Thomas-partey now has the ball
# ghana  now has the ball
# Denis-odoi now has the ball
# Thomas-partey now has the ball
# Denis-odoi now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Afena-Gyan now has the ball
# ghana  now has the ball
# Player Afena-Gyan is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Inaki-williams now has the ball
# ghana  now has the ball
# Player Inaki-williams is shooting
# Inaki-williams Goooooooalll
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Wollacott now has the ball
# ghana  now has the ball
# Alexander-djiku now has the ball
# Player Alexander-djiku is shooting
# Diogo-costa now has the ball
# portugal  now has the ball
# Bruno-fernandes now has the ball
# [0.14040000000000002, 0.11, 0.1008, 0.213]
# Mohammed-kudus now has the ball
# ghana  now has the ball
# Player Mohammed-kudus is shooting
# Raphael-guerreiro now has the ball
# portugal  now has the ball
# Game Over
# Team portugal win [5, 8]
# Empty DataFrame
# Columns: [Team1, Team2, Wins1, Wins2]
# Index: []
# Start Game
# Initialization Complete
# Player Darwin-nunez is shooting
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
#  Rochet now has the ball
# uruguay  now has the ball
# Federico-valverde now has the ball
# Jose-maria-gimenez now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bernardo-silva now has the ball
# portugal  now has the ball
# Player Bernardo-silva is shooting
# Bernardo-silva Goooooooalll
# Luis-suarez now has the ball
# uruguay  now has the ball
# Player Luis-suarez is shooting
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Mathias-olivera now has the ball
# uruguay  now has the ball
# Matias-vecino now has the ball
# Player Matias-vecino is shooting
# Matias-vecino Goooooooalll
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Cristiano-ronaldo Goooooooalll
# Luis-suarez now has the ball
# uruguay  now has the ball
# Player Luis-suarez is shooting
# Luis-suarez Goooooooalll
# Cristiano-ronaldo now has the ball
# portugal  now has the ball
# Player Cristiano-ronaldo is shooting
# Luis-suarez now has the ball
# uruguay  now has the ball
# Player Luis-suarez is shooting
# Bruno-fernandes now has the ball
# portugal  now has the ball
# Pepe now has the ball
# [0.26520000000000005, 0.17640000000000003, 0.1696, 0.2756, 0.45499999999999996, 0.4032, 0.29250000000000004, 0.3822, 0.3744, 0.3358]
# Mathias-olivera now has the ball
# uruguay  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Joao-cancelo now has the ball
# portugal  now has the ball
# [0.26520000000000005, 0.17640000000000003, 0.1696, 0.2756, 0.45499999999999996, 0.4032, 0.29250000000000004, 0.3822, 0.3744, 0.3358]
# Federico-valverde now has the ball
# uruguay  now has the ball
# Jose-maria-gimenez now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Raphael-guerreiro now has the ball
# portugal  now has the ball
# [0.26520000000000005, 0.17640000000000003, 0.1696, 0.2756, 0.45499999999999996, 0.4032, 0.29250000000000004, 0.3822, 0.3744, 0.3358]
# Matias-vecino now has the ball
# uruguay  now has the ball
# Player Matias-vecino is shooting
# William-carvalho now has the ball
# portugal  now has the ball
# [0.26520000000000005, 0.17640000000000003, 0.1696, 0.2756, 0.45499999999999996, 0.4032, 0.29250000000000004, 0.3822, 0.3744, 0.3358]
# Sebastian-coates now has the ball
# uruguay  now has the ball
# Bentancur-rodrigo now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Bruno-fernandes now has the ball
# portugal  now has the ball
# [0.26520000000000005, 0.17640000000000003, 0.1696, 0.2756, 0.45499999999999996, 0.4032, 0.29250000000000004, 0.3822, 0.3744, 0.3358]
# Giorgian-de-arrascaeta now has the ball
# uruguay  now has the ball
# Player Giorgian-de-arrascaeta is shooting
# Ruben-dias now has the ball
# portugal  now has the ball
# William-carvalho now has the ball
# [0.26520000000000005, 0.17640000000000003, 0.1696, 0.2756, 0.45499999999999996, 0.4032, 0.29250000000000004, 0.3822, 0.3744, 0.3358]
# Guillermo-varela now has the ball
# uruguay  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Ruben-dias now has the ball
# portugal  now has the ball
# [0.26520000000000005, 0.17640000000000003, 0.1696, 0.2756, 0.45499999999999996, 0.4032, 0.29250000000000004, 0.3822, 0.3744, 0.3358]
# Matias-vecino now has the ball
# uruguay  now has the ball
# Player Matias-vecino is shooting
# Rafael-leao now has the ball
# portugal  now has the ball
# Player Rafael-leao is shooting
# Jose-maria-gimenez now has the ball
# uruguay  now has the ball
# [0.29109999999999997, 0.2387, 0.22319999999999998, 0.41600000000000004, 0.3408, 0.22769999999999999, 0.51, 0.41340000000000005, 0.3525, 0.36850000000000005]
# Rafael-leao now has the ball
# portugal  now has the ball
# Time:  33

# %%
match
# Out:
# {'germany': 0, 'argentina': 1}

# %%
print(match)
# Out:
# {'germany': 0, 'argentina': 1}

# %%
# Out:
#      Team1      Team2 Wins1 Wins2
# 0  germany  argentina     0     1

# %%
df.dump_csv("group_h.csv")

# %%
df
# Out:
#    germany  argentina
# 0      0.0        1.0

# %%
matches = [("brazil", "serbia"),("brazil", 'switzerland'),('brazil', 'cameroon'),('serbia', "switzerland"),('serbia', "cameroon"),("switzerland", "cameroon")]
df = pd.DataFrame(columns=['Team1', 'Team2','Wins1', "Wins2"])

for t1,t2 in matches:
    team1 = Team(t2, field.field)
    team2 = Team(t1, field.field)


    Pros = []
    match = {
        team1.team_name: 0,
        team2.team_name: 0
    }

    def function_x():
        game = Football(team1, team2, field, 90)
        x = game.play()
        if x is not None:
            match[x.team_name] += 1
     

    for i in range(10):
        function_x()
    
    df.append({'Team1': team1.team_name, 'Team2': team2.team_name, 'Wins1': match[team1.team_name], 'Wins2': match[team2.team_name]}, ignore_index=True)
    print(df)

# %%
df.dump_csv("group_g.csv")
