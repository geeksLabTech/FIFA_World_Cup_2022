# %%
from planning.football import football_model
from planning.search import breadth_first_tree_search
from planning.planning import ForwardPlan
from team import Team
from game import Football
from field import Field
from team import Team
zones = [
    "Defense Left",
    "Defense Center",
    "Defense Right",

    "Midfield Left",
    "Midfield Center",
    "Midfield Right",

    "Attack Left",
    "Attack Center",
    "Attack Right"
]
field = Field("f1", 3, 3, zones)

# %%
team1 = Team('brazil', field.field)
team2 = Team('argentina', field.field)

game = Football(team1, team2, field, 45)

# %%
match = {
    team1.team_name: 0,
    team2.team_name: 0
}
# x = game.play()

# %%
for i in range(30):
    x = game.play()
    match[x.team_name] += 1

match
# Out:
# Start Game
# Initialization Complete
# chekeo de probs [0.44284687275341483, 0.5571531272465852]
# Disparo: (<player.Player object at 0x7f5e9e144490>, 'Shoot')
# Ejecuto disparo
# Raphinha now has the ball
# brazil  now has the ball
# chekeo de probs [0.4678591391839016, 0.5321408608160983]
# Disparo: (<player.Player object at 0x7f5ebaacd1f0>, 'Shoot')
# Ejecuto disparo
# Lautaro-martinez now has the ball
# argentina  now has the ball
# chekeo de probs [0.42072316173035595, 0.579276838269644]
# Disparo: (<player.Player object at 0x7f5e9e144340>, 'Shoot')
# Ejecuto disparo
# Richarlison now has the ball
# brazil  now has the ball
# chekeo de probs [0.4381823546768959, 0.5618176453231042]
# normalized probs: [0.1622630628443082, 0.14423383363938508, 0.13624360705993047, 0.19606786760353903, 0.3611916288528371]
# Angel-di-maria now has the ball
# argentina  now has the ball
# chekeo de probs [0.47207084468664856, 0.5279291553133515]
# normalized probs: [0.04909215017064846, 0.0524778156996587, 0.0390443686006826, 0.040464163822525594, 0.12955631399317405, 0.07159044368600682, 0.11008873720136517, 0.10932423208191126, 0.13913993174061434, 0.08993856655290103, 0.16928327645051194]
# Casemiro now has the ball
# brazil  now has the ball
# chekeo de probs [0.4244256348246675, 0.5755743651753324]
# normalized probs: [0.06728802572703416, 0.059811578424030364, 0.056498152914744575, 0.08130636442016625, 0.08156124330549593, 0.09855316899414092, 0.07204576491985475, 0.1155450946827859, 0.10342418769155248, 0.11418574062769431, 0.14978067829250025]
# Nahuel-molina now has the ball
# argentina  now has the ball
# chekeo de probs [0.31582432134186716, 0.6841756786581329]
# normalized probs: [0.04909215017064846, 0.0524778156996587, 0.0390443686006826, 0.040464163822525594, 0.12955631399317405, 0.07159044368600682, 0.11008873720136517, 0.10932423208191126, 0.13913993174061434, 0.08993856655290103, 0.16928327645051194]
# Alex-telles now has the ball
# brazil  now has the ball
# chekeo de probs [0.28353176693709836, 0.7164682330629016]
# [0.2376, 0.21120000000000003, 0.19949999999999998, 0.28709999999999997, 0.288, 0.348, 0.2544, 0.408, 0.36519999999999997, 0.4032]
# normalized probs: [0.07914196256078875, 0.07034841116514556, 0.06645126906934913, 0.09562987142761972, 0.09592965158883485, 0.1159149956698421, 0.08473785890347078, 0.13590033975084936, 0.12164412763973084, 0.13430151222436879]
# Lionel-messi now has the ball
# argentina  now has the ball
# chekeo de probs [0.6076694298550909, 0.39233057014490924]
# Disparo: (<player.Player object at 0x7f5e9e1446a0>, 'Shoot')
# Ejecuto disparo
# Neymar now has the ball
# brazil  now has the ball
# chekeo de probs [0.575697069100763, 0.42430293089923693]
# normalized probs: [0.1622630628443082, 0.14423383363938508, 0.13624360705993047, 0.19606786760353903, 0.3611916288528371]
# Emiliano-martinez now has the ball
# argentina  now has the ball
# chekeo de probs [1.0, 0.0]
# Nicolas-otamendi now has the ball
# chekeo de probs [0.20349434737923947, 0.7965056526207606]
# Disparo: (<player.Player object at 0x7f5e9e144130>, 'Shoot')
# Ejecuto disparo
# Richarlison now has the ball
# brazil  now has the ball
# chekeo de probs [0.4381823546768959, 0.5618176453231042]
# normalized probs: [0.1622630628443082, 0.14423383363938508, 0.13624360705993047, 0.19606786760353903, 0.3611916288528371]
# Angel-di-maria now has the ball
# argentina  now has the ball
# chekeo de probs [0.47207084468664856, 0.5279291553133515]
# normalized probs: [0.04909215017064846, 0.0524778156996587, 0.0390443686006826, 0.040464163822525594, 0.12955631399317405, 0.07159044368600682, 0.11008873720136517, 0.10932423208191126, 0.13913993174061434, 0.08993856655290103, 0.16928327645051194]
# Alisson now has the ball
# brazil  now has the ball
# chekeo de probs [0.7404568020119483, 0.2595431979880517]
# Thiago-silva now has the ball
# chekeo de probs [0.3865030674846626, 0.6134969325153373]
# Marquinhos now has the ball
# chekeo de probs [0.30713111524719117, 0.6928688847528087]
# Lucas-paqueta now has the ball
# chekeo de probs [0.4700984102952309, 0.5299015897047691]
# Disparo: (<player.Player object at 0x7f5e9e22ecd0>, 'Shoot')
# Ejecuto disparo
# Lautaro-martinez now has the ball
# argentina  now has the ball
# chekeo de probs [0.42072316173035595, 0.579276838269644]
# normalized probs: [0.14011845386533667, 0.14978179551122198, 0.11144014962593518, 0.1154925187032419, 0.48316708229426436]
# Alisson now has the ball
# brazil  now has the ball
# chekeo de probs [1.0, 0.0]
# Thiago-silva now has the ball
# chekeo de probs [1.0, 0.0]
# Marquinhos now has the ball
# chekeo de probs [1.0, 0.0]
# Lucas-paqueta now has the ball
# chekeo de probs [0.4700984102952309, 0.5299015897047691]
# normalized probs: [0.06728802572703416, 0.059811578424030364, 0.056498152914744575, 0.08130636442016625, 0.08156124330549593, 0.09855316899414092, 0.07204576491985475, 0.1155450946827859, 0.10342418769155248, 0.11418574062769431, 0.14978067829250025]
# Nicolas-gonzalez now has the ball
# argentina  now has the ball
# chekeo de probs [0.44284687275341483, 0.5571531272465852]
# normalized probs: [0.04909215017064846, 0.0524778156996587, 0.0390443686006826, 0.040464163822525594, 0.12955631399317405, 0.07159044368600682, 0.11008873720136517, 0.10932423208191126, 0.13913993174061434, 0.08993856655290103, 0.16928327645051194]
# Alisson now has the ball
# brazil  now has the ball
# chekeo de probs [0.7404568020119483, 0.2595431979880517]
# [0.17160000000000003, 0.22619999999999998, 0.11712, 0.27760999999999997, 0.264106, 0.260544]
# normalized probs: [0.13027832186944838, 0.17173051519154556, 0.08891723226893819, 0.21076086791478763, 0.20050866244552756, 0.19780440030975266]
# Marcos-acuna now has the ball
# argentina  now has the ball
# chekeo de probs [0.3347892433227642, 0.6652107566772358]
# [0.1798, 0.1922, 0.14300000000000002, 0.1482, 0.4745, 0.2622, 0.40319999999999995, 0.40040000000000003, 0.5096, 0.3294]
# normalized probs: [0.0590961380443714, 0.06317173377156944, 0.04700082169268694, 0.04870994248151191, 0.15595727198027937, 0.08617912900575185, 0.1325225965488907, 0.13160230073952342, 0.16749383730484801, 0.10826622843056698]
# Richarlison now has the ball
# brazil  now has the ball
# chekeo de probs [0.4381823546768959, 0.5618176453231042]
# normalized probs: [0.06728802572703416, 0.059811578424030364, 0.056498152914744575, 0.08130636442016625, 0.08156124330549593, 0.09855316899414092, 0.07204576491985475, 0.1155450946827859, 0.10342418769155248, 0.11418574062769431, 0.14978067829250025]
# Rodrigo-de-paul now has the ball
# argentina  now has the ball
# chekeo de probs [0.37738246505717915, 0.6226175349428208]
# [0.1798, 0.1922, 0.14300000000000002, 0.1482, 0.4745, 0.2622, 0.40319999999999995, 0.40040000000000003, 0.5096, 0.3294]
# normalized probs: [0.0590961380443714, 0.06317173377156944, 0.04700082169268694, 0.04870994248151191, 0.15595727198027937, 0.08617912900575185, 0.1325225965488907, 0.13160230073952342, 0.16749383730484801, 0.10826622843056698]
# Lucas-paqueta now has the ball
# brazil  now has the ball
# chekeo de probs [0.4700984102952309, 0.5299015897047691]
# Disparo: (<player.Player object at 0x7f5e9e22ecd0>, 'Shoot')
# Ejecuto disparo
# Lionel-messi now has the ball
# argentina  now has the ball
# chekeo de probs [0.6076694298550909, 0.39233057014490924]
# normalized probs: [0.14011845386533667, 0.14978179551122198, 0.11144014962593518, 0.1154925187032419, 0.48316708229426436]
# Alisson now has the ball
# brazil  now has the ball
# chekeo de probs [1.0, 0.0]
# Thiago-silva now has the ball
# chekeo de probs [1.0, 0.0]
# Marquinhos now has the ball
# chekeo de probs [1.0, 0.0]
# Lucas-paqueta now has the ball
# chekeo de probs [0.4700984102952309, 0.5299015897047691]
# Disparo: (<player.Player object at 0x7f5e9e22ecd0>, 'Shoot')
# Ejecuto disparo
# Lautaro-martinez now has the ball
# argentina  now has the ball
# chekeo de probs [0.42072316173035595, 0.579276838269644]
# Disparo: (<player.Player object at 0x7f5e9e144340>, 'Shoot')
# Ejecuto disparo
# Vinicius-junior now has the ball
# brazil  now has the ball
# chekeo de probs [0.4901238270705685, 0.5098761729294313]
# normalized probs: [0.1622630628443082, 0.14423383363938508, 0.13624360705993047, 0.19606786760353903, 0.3611916288528371]
# Emiliano-martinez now has the ball
# argentina  now has the ball
# chekeo de probs [1.0, 0.0]
# Nicolas-otamendi now has the ball
# chekeo de probs [0.20349434737923947, 0.7965056526207606]
# normalized probs: [1.0]
# Alisson now has the ball
# brazil  now has the ball
# chekeo de probs [1.0, 0.0]
# Thiago-silva now has the ball
# chekeo de probs [0.472378432021171, 0.5276215679788289]
# [0.2376, 0.21120000000000003, 0.19949999999999998, 0.28709999999999997]
# normalized probs: [0.25400898011545864, 0.2257857601026299, 0.21327774214239895, 0.3069275176395125]
# Angel-di-maria now has the ball
# argentina  now has the ball
# chekeo de probs [0.47207084468664856, 0.5279291553133515]
# normalized probs: [0.04909215017064846, 0.0524778156996587, 0.0390443686006826, 0.040464163822525594, 0.12955631399317405, 0.07159044368600682, 0.11008873720136517, 0.10932423208191126, 0.13913993174061434, 0.08993856655290103, 0.16928327645051194]
# Alex-telles now has the ball
# brazil  now has the ball
# chekeo de probs [0.28353176693709836, 0.7164682330629016]
# Eder-militao now has the ball
# chekeo de probs [0.30133157981259245, 0.6986684201874076]
# Alex-telles now has the ball
# chekeo de probs [0.28353176693709836, 0.7164682330629016]
# Eder-militao now has the ball
# chekeo de probs [0.30133157981259245, 0.6986684201874076]
# Alex-telles now has the ball
# Game Over
# Team argentina win [4, 5]
# Start Game
# Initialization Complete
# chekeo de probs [0.6076694298550909, 0.39233057014490924]
# Disparo: (<player.Player object at 0x7f5e9e1446a0>, 'Shoot')
# Ejecuto disparo
# Raphinha now has the ball
# brazil  now has the ball
# chekeo de probs [0.4678591391839016, 0.5321408608160983]
# normalized probs: [0.1622630628443082, 0.14423383363938508, 0.13624360705993047, 0.19606786760353903, 0.3611916288528371]
# Emiliano-martinez now has the ball
# argentina  now has the ball
# chekeo de probs [1.0, 0.0]
# Nicolas-otamendi now has the ball
# chekeo de probs [0.20349434737923947, 0.7965056526207606]
# normalized probs: [1.0]
# Alisson now has the ball
# brazil  now has the ball
# chekeo de probs [1.0, 0.0]
# Thiago-silva now has the ball
# chekeo de probs [0.472378432021171, 0.5276215679788289]
# Marquinhos now has the ball
# chekeo de probs [0.3864807802442965, 0.6135192197557034]
# Lucas-paqueta now has the ball
# chekeo de probs [0.4700984102952309, 0.5299015897047691]
# normalized probs: [0.1622630628443082, 0.14423383363938508, 0.13624360705993047, 0.19606786760353903, 0.3611916288528371]
# Lautaro-martinez now has the ball
# argentina  now has the ball
# chekeo de probs [0.42072316173035595, 0.579276838269644]
# Disparo: (<player.Player object at 0x7f5e9e144340>, 'Shoot')
# Ejecuto disparo
# Richarlison now has the ball
# brazil  now has the ball
# chekeo de probs [0.4381823546768959, 0.5618176453231042]
# normalized probs: [0.1622630628443082, 0.14423383363938508, 0.13624360705993047, 0.19606786760353903, 0.3611916288528371]
# Lautaro-martinez now has the ball
# argentina  now has the ball
# chekeo de probs [0.42072316173035595, 0.579276838269644]
# Disparo: (<player.Player object at 0x7f5e9e144340>, 'Shoot')
# Ejecuto disparo
# Raphinha now has the ball
# brazil  now has the ball
# chekeo de probs [0.4678591391839016, 0.5321408608160983]
# normalized probs: [0.1622630628443082, 0.14423383363938508, 0.13624360705993047, 0.19606786760353903, 0.3611916288528371]
# Emiliano-martinez now has the ball
# argentina  now has the ball
# chekeo de probs [1.0, 0.0]
# Nicolas-otamendi now has the ball
# chekeo de probs [0.20349434737923947, 0.7965056526207606]
# normalized probs: [1.0]
# Alisson now has the ball
# brazil  now has the ball
# chekeo de probs [1.0, 0.0]
# Thiago-silva now has the ball
# chekeo de probs [0.472378432021171, 0.5276215679788289]
# [0.2376, 0.21120000000000003, 0.19949999999999998, 0.28709999999999997]
# normalized probs: [0.25400898011545864, 0.2257857601026299, 0.21327774214239895, 0.3069275176395125]
# Angel-di-maria now has the ball
# argentina  now has the ball
# chekeo de probs [0.47207084468664856, 0.5279291553133515]
# normalized probs: [0.04909215017064846, 0.0524778156996587, 0.0390443686006826, 0.040464163822525594, 0.12955631399317405, 0.07159044368600682, 0.11008873720136517, 0.10932423208191126, 0.13913993174061434, 0.08993856655290103, 0.16928327645051194]
# Thiago-silva now has the ball
# brazil  now has the ball
# chekeo de probs [0.3865030674846626, 0.6134969325153373]
# Marquinhos now has the ball
# chekeo de probs [0.30713111524719117, 0.6928688847528087]
# [0.2376, 0.21120000000000003, 0.19949999999999998, 0.28709999999999997, 0.288, 0.348, 0.2544, 0.408, 0.36519999999999997, 0.4032]
# normalized probs: [0.07914196256078875, 0.07034841116514556, 0.06645126906934913, 0.09562987142761972, 0.09592965158883485, 0.1159149956698421, 0.08473785890347078, 0.13590033975084936, 0.12164412763973084, 0.13430151222436879]
# Rodrigo-de-paul now has the ball
# argentina  now has the ball
# chekeo de probs [0.37738246505717915, 0.6226175349428208]
# [0.1798, 0.1922, 0.14300000000000002, 0.1482, 0.4745, 0.2622, 0.40319999999999995, 0.40040000000000003, 0.5096, 0.3294]
# normalized probs: [0.0590961380443714, 0.06317173377156944, 0.04700082169268694, 0.04870994248151191, 0.15595727198027937, 0.08617912900575185, 0.1325225965488907, 0.13160230073952342, 0.16749383730484801, 0.10826622843056698]
# Lucas-paqueta now has the ball
# brazil  now has the ball
# chekeo de probs [0.4700984102952309, 0.5299015897047691]
# normalized probs: [0.06728802572703416, 0.059811578424030364, 0.056498152914744575, 0.08130636442016625, 0.08156124330549593, 0.09855316899414092, 0.07204576491985475, 0.1155450946827859, 0.10342418769155248, 0.11418574062769431, 0.14978067829250025]
# Emiliano-martinez now has the ball
# argentina  now has the ball
# chekeo de probs [0.5832643246964451, 0.4167356753035549]
# Nicolas-otamendi now has the ball
# chekeo de probs [0.20349434737923947, 0.7965056526207606]
# Disparo: (<player.Player object at 0x7f5e9e144130>, 'Shoot')
# Ejecuto disparo
# Neymar now has the ball
# brazil  now has the ball
# chekeo de probs [0.575697069100763, 0.42430293089923693]
# normalized probs: [0.1622630628443082, 0.14423383363938508, 0.13624360705993047, 0.19606786760353903, 0.3611916288528371]
# Angel-di-maria now has the ball
# argentina  now has the ball
# chekeo de probs [0.47207084468664856, 0.5279291553133515]
# normalized probs: [0.04909215017064846, 0.0524778156996587, 0.0390443686006826, 0.040464163822525594, 0.12955631399317405, 0.07159044368600682, 0.11008873720136517, 0.10932423208191126, 0.13913993174061434, 0.08993856655290103, 0.16928327645051194]
# Eder-militao now has the ball
# brazil  now has the ball
# chekeo de probs [0.30133157981259245, 0.6986684201874076]
# [0.2376, 0.21120000000000003, 0.19949999999999998, 0.28709999999999997, 0.288, 0.348, 0.2544, 0.408, 0.36519999999999997, 0.4032]
# normalized probs: [0.07914196256078875, 0.07034841116514556, 0.06645126906934913, 0.09562987142761972, 0.09592965158883485, 0.1159149956698421, 0.08473785890347078, 0.13590033975084936, 0.12164412763973084, 0.13430151222436879]
# Cristian-romero now has the ball
# argentina  now has the ball
# chekeo de probs [0.23525739531310022, 0.7647426046868997]
# Leandro-paredes now has the ball
# chekeo de probs [0.31468531468531463, 0.6853146853146853]
# Cristian-romero now has the ball
# chekeo de probs [0.23525739531310022, 0.7647426046868997]
# [0.1798, 0.1922, 0.14300000000000002, 0.1482, 0.4745, 0.2622, 0.40319999999999995, 0.40040000000000003, 0.5096, 0.3294]
# normalized probs: [0.0590961380443714, 0.06317173377156944, 0.04700082169268694, 0.04870994248151191, 0.15595727198027937, 0.08617912900575185, 0.1325225965488907, 0.13160230073952342, 0.16749383730484801, 0.10826622843056698]
# Marquinhos now has the ball
# brazil  now has the ball
# chekeo de probs [0.30713111524719117, 0.6928688847528087]
# [0.2376, 0.21120000000000003, 0.19949999999999998, 0.28709999999999997, 0.288, 0.348, 0.2544, 0.408, 0.36519999999999997, 0.4032]
# normalized probs: [0.07914196256078875, 0.07034841116514556, 0.06645126906934913, 0.09562987142761972, 0.09592965158883485, 0.1159149956698421, 0.08473785890347078, 0.13590033975084936, 0.12164412763973084, 0.13430151222436879]
# Nahuel-molina now has the ball
# argentina  now has the ball
# chekeo de probs [0.31582432134186716, 0.6841756786581329]
# normalized probs: [0.04909215017064846, 0.0524778156996587, 0.0390443686006826, 0.040464163822525594, 0.12955631399317405, 0.07159044368600682, 0.11008873720136517, 0.10932423208191126, 0.13913993174061434, 0.08993856655290103, 0.16928327645051194]
# Thiago-silva now has the ball
# brazil  now has the ball
# chekeo de probs [0.3865030674846626, 0.6134969325153373]
# Marquinhos now has the ball
# chekeo de probs [0.30713111524719117, 0.6928688847528087]
# [0.2376, 0.21120000000000003, 0.19949999999999998, 0.28709999999999997, 0.288, 0.348, 0.2544, 0.408, 0.36519999999999997, 0.4032]
# normalized probs: [0.07914196256078875, 0.07034841116514556, 0.06645126906934913, 0.09562987142761972, 0.09592965158883485, 0.1159149956698421, 0.08473785890347078, 0.13590033975084936, 0.12164412763973084, 0.13430151222436879]
# Leandro-paredes now has the ball
# argentina  now has the ball
# chekeo de probs [0.31468531468531463, 0.6853146853146853]
# [0.1798, 0.1922, 0.14300000000000002, 0.1482, 0.4745, 0.2622, 0.40319999999999995, 0.40040000000000003, 0.5096, 0.3294]
# normalized probs: [0.0590961380443714, 0.06317173377156944, 0.04700082169268694, 0.04870994248151191, 0.15595727198027937, 0.08617912900575185, 0.1325225965488907, 0.13160230073952342, 0.16749383730484801, 0.10826622843056698]
# Eder-militao now has the ball
# brazil  now has the ball
# chekeo de probs [0.30133157981259245, 0.6986684201874076]
# Alex-telles now has the ball
# chekeo de probs [0.28353176693709836, 0.7164682330629016]
# [0.2376, 0.21120000000000003, 0.19949999999999998, 0.28709999999999997, 0.288, 0.348, 0.2544, 0.408, 0.36519999999999997, 0.4032]
# normalized probs: [0.07914196256078875, 0.07034841116514556, 0.06645126906934913, 0.09562987142761972, 0.09592965158883485, 0.1159149956698421, 0.08473785890347078, 0.13590033975084936, 0.12164412763973084, 0.13430151222436879]
# Cristian-romero now has the ball
# argentina  now has the ball
# chekeo de probs [0.23525739531310022, 0.7647426046868997]
# Leandro-paredes now has the ball
# chekeo de probs [0.31468531468531463, 0.6853146853146853]
# [0.1798, 0.1922, 0.14300000000000002, 0.1482, 0.4745, 0.2622, 0.40319999999999995, 0.40040000000000003, 0.5096, 0.3294]
# normalized probs: [0.0590961380443714, 0.06317173377156944, 0.04700082169268694, 0.04870994248151191, 0.15595727198027937, 0.08617912900575185, 0.1325225965488907, 0.13160230073952342, 0.16749383730484801, 0.10826622843056698]
# Thiago-silva now has the ball
# brazil  now has the ball
# chekeo de probs [0.3865030674846626, 0.6134969325153373]
# [0.2376, 0.21120000000000003, 0.19949999999999998, 0.28709999999999997, 0.288, 0.348, 0.2544, 0.408, 0.36519999999999997, 0.4032]
# normalized probs: [0.07914196256078875, 0.07034841116514556, 0.06645126906934913, 0.09562987142761972, 0.09592965158883485, 0.1159149956698421, 0.08473785890347078, 0.13590033975084936, 0.12164412763973084, 0.13430151222436879]
# Rodrigo-de-paul now has the ball
# argentina  now has the ball
# chekeo de probs [0.37738246505717915, 0.6226175349428208]
# [0.1798, 0.1922, 0.14300000000000002, 0.1482, 0.4745, 0.2622, 0.40319999999999995, 0.40040000000000003, 0.5096, 0.3294]
# normalized probs: [0.0590961380443714, 0.06317173377156944, 0.04700082169268694, 0.04870994248151191, 0.15595727198027937, 0.08617912900575185, 0.1325225965488907, 0.13160230073952342, 0.16749383730484801, 0.10826622843056698]
# Casemiro now has the ball
# brazil  now has the ball
# chekeo de probs [0.44495837187789095, 0.5550416281221091]
# [0.2376, 0.21120000000000003, 0.19949999999999998, 0.28709999999999997, 0.288, 0.348, 0.2544, 0.408, 0.36519999999999997, 0.4032]
# normalized probs: [0.07914196256078875, 0.07034841116514556, 0.06645126906934913, 0.09562987142761972, 0.09592965158883485, 0.1159149956698421, 0.08473785890347078, 0.13590033975084936, 0.12164412763973084, 0.13430151222436879]
# Nicolas-otamendi now has the ball
# argentina  now has the ball
# chekeo de probs [0.20349434737923947, 0.7965056526207606]
# Disparo: (<player.Player object at 0x7f5e9e144130>, 'Shoot')
# Ejecuto disparo
# Vinicius-junior now has the ball
# brazil  now has the ball
# chekeo de probs [0.4901238270705685, 0.5098761729294313]
# Disparo: (<player.Player object at 0x7f5e9d943be0>, 'Shoot')
# Ejecuto disparo
# Angel-di-maria now has the ball
# argentina  now has the ball
# chekeo de probs [0.47207084468664856, 0.5279291553133515]
# Disparo: (<player.Player object at 0x7f5e9e1444c0>, 'Shoot')
# Ejecuto disparo
# Vinicius-junior now has the ball
# brazil  now has the ball
# chekeo de probs [0.4901238270705685, 0.5098761729294313]
# normalized probs: [0.1622630628443082, 0.14423383363938508, 0.13624360705993047, 0.19606786760353903, 0.3611916288528371]
# Angel-di-maria now has the ball
# argentina  now has the ball
# Game Over
# Team argentina win [5, 11]
# Start Game
# Initialization Complete
# chekeo de probs [0.4901238270705685, 0.5098761729294313]
# normalized probs: [0.1622630628443082, 0.14423383363938508, 0.13624360705993047, 0.19606786760353903, 0.3611916288528371]
# Emiliano-martinez now has the ball
# argentina  now has the ball
# chekeo de probs [1.0, 0.0]
# Nicolas-otamendi now has the ball
# Time:  1

# %%
match
# Out:
# {'brazil': 0, 'argentina': 1}
