# %%
from planning.football import football_model
from planning.search import breadth_first_tree_search
from planning.planning import ForwardPlan
from team import Team

from field import Field
from team import Team
zones = [
    "Defense Left",
    "Defense Center",
    "Defense Right",

    "Midfield Left",
    "Midfield Center",
    "Midfield Right",

    "Attack Left",
    "Attack Center",
    "Attack Right"
]
field = Field("f1", 3,3,zones)

# %%
team = Team('brazil', field.field)
variables,problem = football_model(team, team.players[2])
print(variables)
sol= breadth_first_tree_search(ForwardPlan(problem))[0]
# Out:
# {'P': <player.Player object at 0x7f76622d9cc0>, 'P1': <player.Player object at 0x7f76622dace0>, 'P2': <player.Player object at 0x7f76622dba60>, 'P3': <player.Player object at 0x7f767c1c3b50>, 'P4': <player.Player object at 0x7f767c1c3f40>, 'P5': <player.Player object at 0x7f767c1c26e0>, 'P6': <player.Player object at 0x7f7662c381f0>, 'P7': <player.Player object at 0x7f7662c38250>, 'P8': <player.Player object at 0x7f7662c38280>, 'P9': <player.Player object at 0x7f7662c38130>, 'P10': <player.Player object at 0x7f76622d9240>}
# 10
# mira las acciones [Shoot(P6), Shoot(P4), Shoot(P3), Shoot(P5), Shoot(P1), Shoot(P9), Shoot(P2), Shoot(P8), Shoot(P10), Shoot(P), Shoot(P7), Pass(P6, P4), Pass(P6, P3), Pass(P6, P5), Pass(P6, P1), Pass(P6, P9), Pass(P6, P2), Pass(P6, P8), Pass(P6, P10), Pass(P6, P), Pass(P6, P7), Pass(P4, P6), Pass(P4, P3), Pass(P4, P5), Pass(P4, P1), Pass(P4, P9), Pass(P4, P2), Pass(P4, P8), Pass(P4, P10), Pass(P4, P), Pass(P4, P7), Pass(P3, P6), Pass(P3, P4), Pass(P3, P5), Pass(P3, P1), Pass(P3, P9), Pass(P3, P2), Pass(P3, P8), Pass(P3, P10), Pass(P3, P), Pass(P3, P7), Pass(P5, P6), Pass(P5, P4), Pass(P5, P3), Pass(P5, P1), Pass(P5, P9), Pass(P5, P2), Pass(P5, P8), Pass(P5, P10), Pass(P5, P), Pass(P5, P7), Pass(P1, P6), Pass(P1, P4), Pass(P1, P3), Pass(P1, P5), Pass(P1, P9), Pass(P1, P2), Pass(P1, P8), Pass(P1, P10), Pass(P1, P), Pass(P1, P7), Pass(P9, P6), Pass(P9, P4), Pass(P9, P3), Pass(P9, P5), Pass(P9, P1), Pass(P9, P2), Pass(P9, P8), Pass(P9, P10), Pass(P9, P), Pass(P9, P7), Pass(P2, P6), Pass(P2, P4), Pass(P2, P3), Pass(P2, P5), Pass(P2, P1), Pass(P2, P9), Pass(P2, P8), Pass(P2, P10), Pass(P2, P), Pass(P2, P7), Pass(P8, P6), Pass(P8, P4), Pass(P8, P3), Pass(P8, P5), Pass(P8, P1), Pass(P8, P9), Pass(P8, P2), Pass(P8, P10), Pass(P8, P), Pass(P8, P7), Pass(P10, P6), Pass(P10, P4), Pass(P10, P3), Pass(P10, P5), Pass(P10, P1), Pass(P10, P9), Pass(P10, P2), Pass(P10, P8), Pass(P10, P), Pass(P10, P7), Pass(P, P6), Pass(P, P4), Pass(P, P3), Pass(P, P5), Pass(P, P1), Pass(P, P9), Pass(P, P2), Pass(P, P8), Pass(P, P10), Pass(P, P7), Pass(P7, P6), Pass(P7, P4), Pass(P7, P3), Pass(P7, P5), Pass(P7, P1), Pass(P7, P9), Pass(P7, P2), Pass(P7, P8), Pass(P7, P10), Pass(P7, P)]
# precondiciones [BallPocesion(P), Player(P), Player(P1), Player(P2), Player(P3), Player(P4), Player(P5), Player(P6), Player(P7), Player(P8), Player(P9), Player(P10), Player(P), Player(P1), Player(P2), Player(P3), Player(P4), Player(P5), Player(P6), Player(P7), Player(P8), Player(P9), Player(P10)]
#
# accion:  Shoot(P6) precondiciones:  [BallPocesion(P6), Player(P6)]
#
# accion:  Shoot(P4) precondiciones:  [BallPocesion(P4), Player(P4)]
#
# accion:  Shoot(P3) precondiciones:  [BallPocesion(P3), Player(P3)]
#
# accion:  Shoot(P5) precondiciones:  [BallPocesion(P5), Player(P5)]
#
# accion:  Shoot(P1) precondiciones:  [BallPocesion(P1), Player(P1)]
#
# accion:  Shoot(P9) precondiciones:  [BallPocesion(P9), Player(P9)]
#
# accion:  Shoot(P2) precondiciones:  [BallPocesion(P2), Player(P2)]
#
# accion:  Shoot(P8) precondiciones:  [BallPocesion(P8), Player(P8)]
#
# accion:  Shoot(P10) precondiciones:  [BallPocesion(P10), Player(P10)]
#
# accion:  Shoot(P) precondiciones:  [BallPocesion(P), Player(P)]
#
# accion:  Shoot(P7) precondiciones:  [BallPocesion(P7), Player(P7)]
#
# accion:  Pass(P6, P4) precondiciones:  [BallPocesion(P6), Player(P6), Player(P4)]
#
# accion:  Pass(P6, P3) precondiciones:  [BallPocesion(P6), Player(P6), Player(P3)]
#
# accion:  Pass(P6, P5) precondiciones:  [BallPocesion(P6), Player(P6), Player(P5)]
#
# accion:  Pass(P6, P1) precondiciones:  [BallPocesion(P6), Player(P6), Player(P1)]
#
# accion:  Pass(P6, P9) precondiciones:  [BallPocesion(P6), Player(P6), Player(P9)]
#
# accion:  Pass(P6, P2) precondiciones:  [BallPocesion(P6), Player(P6), Player(P2)]
#
# accion:  Pass(P6, P8) precondiciones:  [BallPocesion(P6), Player(P6), Player(P8)]
#
# accion:  Pass(P6, P10) precondiciones:  [BallPocesion(P6), Player(P6), Player(P10)]
#
# accion:  Pass(P6, P) precondiciones:  [BallPocesion(P6), Player(P6), Player(P)]
#
# accion:  Pass(P6, P7) precondiciones:  [BallPocesion(P6), Player(P6), Player(P7)]
#
# accion:  Pass(P4, P6) precondiciones:  [BallPocesion(P4), Player(P4), Player(P6)]
#
# accion:  Pass(P4, P3) precondiciones:  [BallPocesion(P4), Player(P4), Player(P3)]
#
# accion:  Pass(P4, P5) precondiciones:  [BallPocesion(P4), Player(P4), Player(P5)]
#
# accion:  Pass(P4, P1) precondiciones:  [BallPocesion(P4), Player(P4), Player(P1)]
#
# accion:  Pass(P4, P9) precondiciones:  [BallPocesion(P4), Player(P4), Player(P9)]
#
# accion:  Pass(P4, P2) precondiciones:  [BallPocesion(P4), Player(P4), Player(P2)]
#
# accion:  Pass(P4, P8) precondiciones:  [BallPocesion(P4), Player(P4), Player(P8)]
#
# accion:  Pass(P4, P10) precondiciones:  [BallPocesion(P4), Player(P4), Player(P10)]
#
# accion:  Pass(P4, P) precondiciones:  [BallPocesion(P4), Player(P4), Player(P)]
#
# accion:  Pass(P4, P7) precondiciones:  [BallPocesion(P4), Player(P4), Player(P7)]
#
# accion:  Pass(P3, P6) precondiciones:  [BallPocesion(P3), Player(P3), Player(P6)]
#
# accion:  Pass(P3, P4) precondiciones:  [BallPocesion(P3), Player(P3), Player(P4)]
#
# accion:  Pass(P3, P5) precondiciones:  [BallPocesion(P3), Player(P3), Player(P5)]
#
# accion:  Pass(P3, P1) precondiciones:  [BallPocesion(P3), Player(P3), Player(P1)]
#
# accion:  Pass(P3, P9) precondiciones:  [BallPocesion(P3), Player(P3), Player(P9)]
#
# accion:  Pass(P3, P2) precondiciones:  [BallPocesion(P3), Player(P3), Player(P2)]
#
# accion:  Pass(P3, P8) precondiciones:  [BallPocesion(P3), Player(P3), Player(P8)]
#
# accion:  Pass(P3, P10) precondiciones:  [BallPocesion(P3), Player(P3), Player(P10)]
#
# accion:  Pass(P3, P) precondiciones:  [BallPocesion(P3), Player(P3), Player(P)]
#
# accion:  Pass(P3, P7) precondiciones:  [BallPocesion(P3), Player(P3), Player(P7)]
#
# accion:  Pass(P5, P6) precondiciones:  [BallPocesion(P5), Player(P5), Player(P6)]
#
# accion:  Pass(P5, P4) precondiciones:  [BallPocesion(P5), Player(P5), Player(P4)]
#
# accion:  Pass(P5, P3) precondiciones:  [BallPocesion(P5), Player(P5), Player(P3)]
#
# accion:  Pass(P5, P1) precondiciones:  [BallPocesion(P5), Player(P5), Player(P1)]
#
# accion:  Pass(P5, P9) precondiciones:  [BallPocesion(P5), Player(P5), Player(P9)]
#
# accion:  Pass(P5, P2) precondiciones:  [BallPocesion(P5), Player(P5), Player(P2)]
#
# accion:  Pass(P5, P8) precondiciones:  [BallPocesion(P5), Player(P5), Player(P8)]
#
# accion:  Pass(P5, P10) precondiciones:  [BallPocesion(P5), Player(P5), Player(P10)]
#
# accion:  Pass(P5, P) precondiciones:  [BallPocesion(P5), Player(P5), Player(P)]
#
# accion:  Pass(P5, P7) precondiciones:  [BallPocesion(P5), Player(P5), Player(P7)]
#
# accion:  Pass(P1, P6) precondiciones:  [BallPocesion(P1), Player(P1), Player(P6)]
#
# accion:  Pass(P1, P4) precondiciones:  [BallPocesion(P1), Player(P1), Player(P4)]
#
# accion:  Pass(P1, P3) precondiciones:  [BallPocesion(P1), Player(P1), Player(P3)]
#
# accion:  Pass(P1, P5) precondiciones:  [BallPocesion(P1), Player(P1), Player(P5)]
#
# accion:  Pass(P1, P9) precondiciones:  [BallPocesion(P1), Player(P1), Player(P9)]
#
# accion:  Pass(P1, P2) precondiciones:  [BallPocesion(P1), Player(P1), Player(P2)]
#
# accion:  Pass(P1, P8) precondiciones:  [BallPocesion(P1), Player(P1), Player(P8)]
#
# accion:  Pass(P1, P10) precondiciones:  [BallPocesion(P1), Player(P1), Player(P10)]
#
# accion:  Pass(P1, P) precondiciones:  [BallPocesion(P1), Player(P1), Player(P)]
#
# accion:  Pass(P1, P7) precondiciones:  [BallPocesion(P1), Player(P1), Player(P7)]
#
# accion:  Pass(P9, P6) precondiciones:  [BallPocesion(P9), Player(P9), Player(P6)]
#
# accion:  Pass(P9, P4) precondiciones:  [BallPocesion(P9), Player(P9), Player(P4)]
#
# accion:  Pass(P9, P3) precondiciones:  [BallPocesion(P9), Player(P9), Player(P3)]
#
# accion:  Pass(P9, P5) precondiciones:  [BallPocesion(P9), Player(P9), Player(P5)]
#
# accion:  Pass(P9, P1) precondiciones:  [BallPocesion(P9), Player(P9), Player(P1)]
#
# accion:  Pass(P9, P2) precondiciones:  [BallPocesion(P9), Player(P9), Player(P2)]
#
# accion:  Pass(P9, P8) precondiciones:  [BallPocesion(P9), Player(P9), Player(P8)]
#
# accion:  Pass(P9, P10) precondiciones:  [BallPocesion(P9), Player(P9), Player(P10)]
#
# accion:  Pass(P9, P) precondiciones:  [BallPocesion(P9), Player(P9), Player(P)]
#
# accion:  Pass(P9, P7) precondiciones:  [BallPocesion(P9), Player(P9), Player(P7)]
#
# accion:  Pass(P2, P6) precondiciones:  [BallPocesion(P2), Player(P2), Player(P6)]
#
# accion:  Pass(P2, P4) precondiciones:  [BallPocesion(P2), Player(P2), Player(P4)]
#
# accion:  Pass(P2, P3) precondiciones:  [BallPocesion(P2), Player(P2), Player(P3)]
#
# accion:  Pass(P2, P5) precondiciones:  [BallPocesion(P2), Player(P2), Player(P5)]
#
# accion:  Pass(P2, P1) precondiciones:  [BallPocesion(P2), Player(P2), Player(P1)]
#
# accion:  Pass(P2, P9) precondiciones:  [BallPocesion(P2), Player(P2), Player(P9)]
#
# accion:  Pass(P2, P8) precondiciones:  [BallPocesion(P2), Player(P2), Player(P8)]
#
# accion:  Pass(P2, P10) precondiciones:  [BallPocesion(P2), Player(P2), Player(P10)]
#
# accion:  Pass(P2, P) precondiciones:  [BallPocesion(P2), Player(P2), Player(P)]
#
# accion:  Pass(P2, P7) precondiciones:  [BallPocesion(P2), Player(P2), Player(P7)]
#
# accion:  Pass(P8, P6) precondiciones:  [BallPocesion(P8), Player(P8), Player(P6)]
#
# accion:  Pass(P8, P4) precondiciones:  [BallPocesion(P8), Player(P8), Player(P4)]
#
# accion:  Pass(P8, P3) precondiciones:  [BallPocesion(P8), Player(P8), Player(P3)]
#
# accion:  Pass(P8, P5) precondiciones:  [BallPocesion(P8), Player(P8), Player(P5)]
#
# accion:  Pass(P8, P1) precondiciones:  [BallPocesion(P8), Player(P8), Player(P1)]
#
# accion:  Pass(P8, P9) precondiciones:  [BallPocesion(P8), Player(P8), Player(P9)]
#
# accion:  Pass(P8, P2) precondiciones:  [BallPocesion(P8), Player(P8), Player(P2)]
#
# accion:  Pass(P8, P10) precondiciones:  [BallPocesion(P8), Player(P8), Player(P10)]
#
# accion:  Pass(P8, P) precondiciones:  [BallPocesion(P8), Player(P8), Player(P)]
#
# accion:  Pass(P8, P7) precondiciones:  [BallPocesion(P8), Player(P8), Player(P7)]
#
# accion:  Pass(P10, P6) precondiciones:  [BallPocesion(P10), Player(P10), Player(P6)]
#
# accion:  Pass(P10, P4) precondiciones:  [BallPocesion(P10), Player(P10), Player(P4)]
#
# accion:  Pass(P10, P3) precondiciones:  [BallPocesion(P10), Player(P10), Player(P3)]
#
# accion:  Pass(P10, P5) precondiciones:  [BallPocesion(P10), Player(P10), Player(P5)]
#
# accion:  Pass(P10, P1) precondiciones:  [BallPocesion(P10), Player(P10), Player(P1)]
#
# accion:  Pass(P10, P9) precondiciones:  [BallPocesion(P10), Player(P10), Player(P9)]
#
# accion:  Pass(P10, P2) precondiciones:  [BallPocesion(P10), Player(P10), Player(P2)]
#
# accion:  Pass(P10, P8) precondiciones:  [BallPocesion(P10), Player(P10), Player(P8)]
#
# accion:  Pass(P10, P) precondiciones:  [BallPocesion(P10), Player(P10), Player(P)]
#
# accion:  Pass(P10, P7) precondiciones:  [BallPocesion(P10), Player(P10), Player(P7)]
#
# accion:  Pass(P, P6) precondiciones:  [BallPocesion(P), Player(P), Player(P6)]
#
# accion:  Pass(P, P4) precondiciones:  [BallPocesion(P), Player(P), Player(P4)]
#
# accion:  Pass(P, P3) precondiciones:  [BallPocesion(P), Player(P), Player(P3)]
#
# accion:  Pass(P, P5) precondiciones:  [BallPocesion(P), Player(P), Player(P5)]
#
# accion:  Pass(P, P1) precondiciones:  [BallPocesion(P), Player(P), Player(P1)]
#
# accion:  Pass(P, P9) precondiciones:  [BallPocesion(P), Player(P), Player(P9)]
#
# accion:  Pass(P, P2) precondiciones:  [BallPocesion(P), Player(P), Player(P2)]
#
# accion:  Pass(P, P8) precondiciones:  [BallPocesion(P), Player(P), Player(P8)]
#
# accion:  Pass(P, P10) precondiciones:  [BallPocesion(P), Player(P), Player(P10)]
#
# accion:  Pass(P, P7) precondiciones:  [BallPocesion(P), Player(P), Player(P7)]
#
# accion:  Pass(P7, P6) precondiciones:  [BallPocesion(P7), Player(P7), Player(P6)]
#
# accion:  Pass(P7, P4) precondiciones:  [BallPocesion(P7), Player(P7), Player(P4)]
#
# accion:  Pass(P7, P3) precondiciones:  [BallPocesion(P7), Player(P7), Player(P3)]
#
# accion:  Pass(P7, P5) precondiciones:  [BallPocesion(P7), Player(P7), Player(P5)]
#
# accion:  Pass(P7, P1) precondiciones:  [BallPocesion(P7), Player(P7), Player(P1)]
#
# accion:  Pass(P7, P9) precondiciones:  [BallPocesion(P7), Player(P7), Player(P9)]
#
# accion:  Pass(P7, P2) precondiciones:  [BallPocesion(P7), Player(P7), Player(P2)]
#
# accion:  Pass(P7, P8) precondiciones:  [BallPocesion(P7), Player(P7), Player(P8)]
#
# accion:  Pass(P7, P10) precondiciones:  [BallPocesion(P7), Player(P7), Player(P10)]
#
# accion:  Pass(P7, P) precondiciones:  [BallPocesion(P7), Player(P7), Player(P)]
#
# acciones q se pueden hacer [Shoot(P), Pass(P, P6), Pass(P, P4), Pass(P, P3), Pass(P, P5), Pass(P, P1), Pass(P, P9), Pass(P, P2), Pass(P, P8), Pass(P, P10), Pass(P, P7)]
# 9
# mira las acciones [Shoot(P6), Shoot(P4), Shoot(P3), Shoot(P5), Shoot(P1), Shoot(P9), Shoot(P2), Shoot(P8), Shoot(P10), Shoot(P), Shoot(P7), Pass(P6, P4), Pass(P6, P3), Pass(P6, P5), Pass(P6, P1), Pass(P6, P9), Pass(P6, P2), Pass(P6, P8), Pass(P6, P10), Pass(P6, P), Pass(P6, P7), Pass(P4, P6), Pass(P4, P3), Pass(P4, P5), Pass(P4, P1), Pass(P4, P9), Pass(P4, P2), Pass(P4, P8), Pass(P4, P10), Pass(P4, P), Pass(P4, P7), Pass(P3, P6), Pass(P3, P4), Pass(P3, P5), Pass(P3, P1), Pass(P3, P9), Pass(P3, P2), Pass(P3, P8), Pass(P3, P10), Pass(P3, P), Pass(P3, P7), Pass(P5, P6), Pass(P5, P4), Pass(P5, P3), Pass(P5, P1), Pass(P5, P9), Pass(P5, P2), Pass(P5, P8), Pass(P5, P10), Pass(P5, P), Pass(P5, P7), Pass(P1, P6), Pass(P1, P4), Pass(P1, P3), Pass(P1, P5), Pass(P1, P9), Pass(P1, P2), Pass(P1, P8), Pass(P1, P10), Pass(P1, P), Pass(P1, P7), Pass(P9, P6), Pass(P9, P4), Pass(P9, P3), Pass(P9, P5), Pass(P9, P1), Pass(P9, P2), Pass(P9, P8), Pass(P9, P10), Pass(P9, P), Pass(P9, P7), Pass(P2, P6), Pass(P2, P4), Pass(P2, P3), Pass(P2, P5), Pass(P2, P1), Pass(P2, P9), Pass(P2, P8), Pass(P2, P10), Pass(P2, P), Pass(P2, P7), Pass(P8, P6), Pass(P8, P4), Pass(P8, P3), Pass(P8, P5), Pass(P8, P1), Pass(P8, P9), Pass(P8, P2), Pass(P8, P10), Pass(P8, P), Pass(P8, P7), Pass(P10, P6), Pass(P10, P4), Pass(P10, P3), Pass(P10, P5), Pass(P10, P1), Pass(P10, P9), Pass(P10, P2), Pass(P10, P8), Pass(P10, P), Pass(P10, P7), Pass(P, P6), Pass(P, P4), Pass(P, P3), Pass(P, P5), Pass(P, P1), Pass(P, P9), Pass(P, P2), Pass(P, P8), Pass(P, P10), Pass(P, P7), Pass(P7, P6), Pass(P7, P4), Pass(P7, P3), Pass(P7, P5), Pass(P7, P1), Pass(P7, P9), Pass(P7, P2), Pass(P7, P8), Pass(P7, P10), Pass(P7, P)]
# precondiciones [Player(P), Player(P1), Player(P2), Player(P3), Player(P4), Player(P5), Player(P6), Player(P7), Player(P8), Player(P9), Player(P10), Player(P), Player(P1), Player(P2), Player(P3), Player(P4), Player(P5), Player(P6), Player(P7), Player(P8), Player(P9), Player(P10), BallInGoal, NotBallPocesion(P)]
#
# accion:  Shoot(P6) precondiciones:  [BallPocesion(P6), Player(P6)]
#
# accion:  Shoot(P4) precondiciones:  [BallPocesion(P4), Player(P4)]
#
# accion:  Shoot(P3) precondiciones:  [BallPocesion(P3), Player(P3)]
#
# accion:  Shoot(P5) precondiciones:  [BallPocesion(P5), Player(P5)]
#
# accion:  Shoot(P1) precondiciones:  [BallPocesion(P1), Player(P1)]
#
# accion:  Shoot(P9) precondiciones:  [BallPocesion(P9), Player(P9)]
#
# accion:  Shoot(P2) precondiciones:  [BallPocesion(P2), Player(P2)]
#
# accion:  Shoot(P8) precondiciones:  [BallPocesion(P8), Player(P8)]
#
# accion:  Shoot(P10) precondiciones:  [BallPocesion(P10), Player(P10)]
#
# accion:  Shoot(P) precondiciones:  [BallPocesion(P), Player(P)]
#
# accion:  Shoot(P7) precondiciones:  [BallPocesion(P7), Player(P7)]
#
# accion:  Pass(P6, P4) precondiciones:  [BallPocesion(P6), Player(P6), Player(P4)]
#
# accion:  Pass(P6, P3) precondiciones:  [BallPocesion(P6), Player(P6), Player(P3)]
#
# accion:  Pass(P6, P5) precondiciones:  [BallPocesion(P6), Player(P6), Player(P5)]
#
# accion:  Pass(P6, P1) precondiciones:  [BallPocesion(P6), Player(P6), Player(P1)]
#
# accion:  Pass(P6, P9) precondiciones:  [BallPocesion(P6), Player(P6), Player(P9)]
#
# accion:  Pass(P6, P2) precondiciones:  [BallPocesion(P6), Player(P6), Player(P2)]
#
# accion:  Pass(P6, P8) precondiciones:  [BallPocesion(P6), Player(P6), Player(P8)]
#
# accion:  Pass(P6, P10) precondiciones:  [BallPocesion(P6), Player(P6), Player(P10)]
#
# accion:  Pass(P6, P) precondiciones:  [BallPocesion(P6), Player(P6), Player(P)]
#
# accion:  Pass(P6, P7) precondiciones:  [BallPocesion(P6), Player(P6), Player(P7)]
#
# accion:  Pass(P4, P6) precondiciones:  [BallPocesion(P4), Player(P4), Player(P6)]
#
# accion:  Pass(P4, P3) precondiciones:  [BallPocesion(P4), Player(P4), Player(P3)]
#
# accion:  Pass(P4, P5) precondiciones:  [BallPocesion(P4), Player(P4), Player(P5)]
#
# accion:  Pass(P4, P1) precondiciones:  [BallPocesion(P4), Player(P4), Player(P1)]
#
# accion:  Pass(P4, P9) precondiciones:  [BallPocesion(P4), Player(P4), Player(P9)]
#
# accion:  Pass(P4, P2) precondiciones:  [BallPocesion(P4), Player(P4), Player(P2)]
#
# accion:  Pass(P4, P8) precondiciones:  [BallPocesion(P4), Player(P4), Player(P8)]
#
# accion:  Pass(P4, P10) precondiciones:  [BallPocesion(P4), Player(P4), Player(P10)]
#
# accion:  Pass(P4, P) precondiciones:  [BallPocesion(P4), Player(P4), Player(P)]
#
# accion:  Pass(P4, P7) precondiciones:  [BallPocesion(P4), Player(P4), Player(P7)]
#
# accion:  Pass(P3, P6) precondiciones:  [BallPocesion(P3), Player(P3), Player(P6)]
#
# accion:  Pass(P3, P4) precondiciones:  [BallPocesion(P3), Player(P3), Player(P4)]
#
# accion:  Pass(P3, P5) precondiciones:  [BallPocesion(P3), Player(P3), Player(P5)]
#
# accion:  Pass(P3, P1) precondiciones:  [BallPocesion(P3), Player(P3), Player(P1)]
#
# accion:  Pass(P3, P9) precondiciones:  [BallPocesion(P3), Player(P3), Player(P9)]
#
# accion:  Pass(P3, P2) precondiciones:  [BallPocesion(P3), Player(P3), Player(P2)]
#
# accion:  Pass(P3, P8) precondiciones:  [BallPocesion(P3), Player(P3), Player(P8)]
#
# accion:  Pass(P3, P10) precondiciones:  [BallPocesion(P3), Player(P3), Player(P10)]
#
# accion:  Pass(P3, P) precondiciones:  [BallPocesion(P3), Player(P3), Player(P)]
#
# accion:  Pass(P3, P7) precondiciones:  [BallPocesion(P3), Player(P3), Player(P7)]
#
# accion:  Pass(P5, P6) precondiciones:  [BallPocesion(P5), Player(P5), Player(P6)]
#
# accion:  Pass(P5, P4) precondiciones:  [BallPocesion(P5), Player(P5), Player(P4)]
#
# accion:  Pass(P5, P3) precondiciones:  [BallPocesion(P5), Player(P5), Player(P3)]
#
# accion:  Pass(P5, P1) precondiciones:  [BallPocesion(P5), Player(P5), Player(P1)]
#
# accion:  Pass(P5, P9) precondiciones:  [BallPocesion(P5), Player(P5), Player(P9)]
#
# accion:  Pass(P5, P2) precondiciones:  [BallPocesion(P5), Player(P5), Player(P2)]
#
# accion:  Pass(P5, P8) precondiciones:  [BallPocesion(P5), Player(P5), Player(P8)]
#
# accion:  Pass(P5, P10) precondiciones:  [BallPocesion(P5), Player(P5), Player(P10)]
#
# accion:  Pass(P5, P) precondiciones:  [BallPocesion(P5), Player(P5), Player(P)]
#
# accion:  Pass(P5, P7) precondiciones:  [BallPocesion(P5), Player(P5), Player(P7)]
#
# accion:  Pass(P1, P6) precondiciones:  [BallPocesion(P1), Player(P1), Player(P6)]
#
# accion:  Pass(P1, P4) precondiciones:  [BallPocesion(P1), Player(P1), Player(P4)]
#
# accion:  Pass(P1, P3) precondiciones:  [BallPocesion(P1), Player(P1), Player(P3)]
#
# accion:  Pass(P1, P5) precondiciones:  [BallPocesion(P1), Player(P1), Player(P5)]
#
# accion:  Pass(P1, P9) precondiciones:  [BallPocesion(P1), Player(P1), Player(P9)]
#
# accion:  Pass(P1, P2) precondiciones:  [BallPocesion(P1), Player(P1), Player(P2)]
#
# accion:  Pass(P1, P8) precondiciones:  [BallPocesion(P1), Player(P1), Player(P8)]
#
# accion:  Pass(P1, P10) precondiciones:  [BallPocesion(P1), Player(P1), Player(P10)]
#
# accion:  Pass(P1, P) precondiciones:  [BallPocesion(P1), Player(P1), Player(P)]
#
# accion:  Pass(P1, P7) precondiciones:  [BallPocesion(P1), Player(P1), Player(P7)]
#
# accion:  Pass(P9, P6) precondiciones:  [BallPocesion(P9), Player(P9), Player(P6)]
#
# accion:  Pass(P9, P4) precondiciones:  [BallPocesion(P9), Player(P9), Player(P4)]
#
# accion:  Pass(P9, P3) precondiciones:  [BallPocesion(P9), Player(P9), Player(P3)]
#
# accion:  Pass(P9, P5) precondiciones:  [BallPocesion(P9), Player(P9), Player(P5)]
#
# accion:  Pass(P9, P1) precondiciones:  [BallPocesion(P9), Player(P9), Player(P1)]
#
# accion:  Pass(P9, P2) precondiciones:  [BallPocesion(P9), Player(P9), Player(P2)]
#
# accion:  Pass(P9, P8) precondiciones:  [BallPocesion(P9), Player(P9), Player(P8)]
#
# accion:  Pass(P9, P10) precondiciones:  [BallPocesion(P9), Player(P9), Player(P10)]
#
# accion:  Pass(P9, P) precondiciones:  [BallPocesion(P9), Player(P9), Player(P)]
#
# accion:  Pass(P9, P7) precondiciones:  [BallPocesion(P9), Player(P9), Player(P7)]
#
# accion:  Pass(P2, P6) precondiciones:  [BallPocesion(P2), Player(P2), Player(P6)]
#
# accion:  Pass(P2, P4) precondiciones:  [BallPocesion(P2), Player(P2), Player(P4)]
#
# accion:  Pass(P2, P3) precondiciones:  [BallPocesion(P2), Player(P2), Player(P3)]
#
# accion:  Pass(P2, P5) precondiciones:  [BallPocesion(P2), Player(P2), Player(P5)]
#
# accion:  Pass(P2, P1) precondiciones:  [BallPocesion(P2), Player(P2), Player(P1)]
#
# accion:  Pass(P2, P9) precondiciones:  [BallPocesion(P2), Player(P2), Player(P9)]
#
# accion:  Pass(P2, P8) precondiciones:  [BallPocesion(P2), Player(P2), Player(P8)]
#
# accion:  Pass(P2, P10) precondiciones:  [BallPocesion(P2), Player(P2), Player(P10)]
#
# accion:  Pass(P2, P) precondiciones:  [BallPocesion(P2), Player(P2), Player(P)]
#
# accion:  Pass(P2, P7) precondiciones:  [BallPocesion(P2), Player(P2), Player(P7)]
#
# accion:  Pass(P8, P6) precondiciones:  [BallPocesion(P8), Player(P8), Player(P6)]
#
# accion:  Pass(P8, P4) precondiciones:  [BallPocesion(P8), Player(P8), Player(P4)]
#
# accion:  Pass(P8, P3) precondiciones:  [BallPocesion(P8), Player(P8), Player(P3)]
#
# accion:  Pass(P8, P5) precondiciones:  [BallPocesion(P8), Player(P8), Player(P5)]
#
# accion:  Pass(P8, P1) precondiciones:  [BallPocesion(P8), Player(P8), Player(P1)]
#
# accion:  Pass(P8, P9) precondiciones:  [BallPocesion(P8), Player(P8), Player(P9)]
#
# accion:  Pass(P8, P2) precondiciones:  [BallPocesion(P8), Player(P8), Player(P2)]
#
# accion:  Pass(P8, P10) precondiciones:  [BallPocesion(P8), Player(P8), Player(P10)]
#
# accion:  Pass(P8, P) precondiciones:  [BallPocesion(P8), Player(P8), Player(P)]
#
# accion:  Pass(P8, P7) precondiciones:  [BallPocesion(P8), Player(P8), Player(P7)]
#
# accion:  Pass(P10, P6) precondiciones:  [BallPocesion(P10), Player(P10), Player(P6)]
#
# accion:  Pass(P10, P4) precondiciones:  [BallPocesion(P10), Player(P10), Player(P4)]
#
# accion:  Pass(P10, P3) precondiciones:  [BallPocesion(P10), Player(P10), Player(P3)]
#
# accion:  Pass(P10, P5) precondiciones:  [BallPocesion(P10), Player(P10), Player(P5)]
#
# accion:  Pass(P10, P1) precondiciones:  [BallPocesion(P10), Player(P10), Player(P1)]
#
# accion:  Pass(P10, P9) precondiciones:  [BallPocesion(P10), Player(P10), Player(P9)]
#
# accion:  Pass(P10, P2) precondiciones:  [BallPocesion(P10), Player(P10), Player(P2)]
#
# accion:  Pass(P10, P8) precondiciones:  [BallPocesion(P10), Player(P10), Player(P8)]
#
# accion:  Pass(P10, P) precondiciones:  [BallPocesion(P10), Player(P10), Player(P)]
#
# accion:  Pass(P10, P7) precondiciones:  [BallPocesion(P10), Player(P10), Player(P7)]
#
# accion:  Pass(P, P6) precondiciones:  [BallPocesion(P), Player(P), Player(P6)]
#
# accion:  Pass(P, P4) precondiciones:  [BallPocesion(P), Player(P), Player(P4)]
#
# accion:  Pass(P, P3) precondiciones:  [BallPocesion(P), Player(P), Player(P3)]
#
# accion:  Pass(P, P5) precondiciones:  [BallPocesion(P), Player(P), Player(P5)]
#
# accion:  Pass(P, P1) precondiciones:  [BallPocesion(P), Player(P), Player(P1)]
#
# accion:  Pass(P, P9) precondiciones:  [BallPocesion(P), Player(P), Player(P9)]
#
# accion:  Pass(P, P2) precondiciones:  [BallPocesion(P), Player(P), Player(P2)]
#
# accion:  Pass(P, P8) precondiciones:  [BallPocesion(P), Player(P), Player(P8)]
#
# accion:  Pass(P, P10) precondiciones:  [BallPocesion(P), Player(P), Player(P10)]
#
# accion:  Pass(P, P7) precondiciones:  [BallPocesion(P), Player(P), Player(P7)]
#
# accion:  Pass(P7, P6) precondiciones:  [BallPocesion(P7), Player(P7), Player(P6)]
#
# accion:  Pass(P7, P4) precondiciones:  [BallPocesion(P7), Player(P7), Player(P4)]
#
# accion:  Pass(P7, P3) precondiciones:  [BallPocesion(P7), Player(P7), Player(P3)]
#
# accion:  Pass(P7, P5) precondiciones:  [BallPocesion(P7), Player(P7), Player(P5)]
#
# accion:  Pass(P7, P1) precondiciones:  [BallPocesion(P7), Player(P7), Player(P1)]
#
# accion:  Pass(P7, P9) precondiciones:  [BallPocesion(P7), Player(P7), Player(P9)]
#
# accion:  Pass(P7, P2) precondiciones:  [BallPocesion(P7), Player(P7), Player(P2)]
#
# accion:  Pass(P7, P8) precondiciones:  [BallPocesion(P7), Player(P7), Player(P8)]
#
# accion:  Pass(P7, P10) precondiciones:  [BallPocesion(P7), Player(P7), Player(P10)]
#
# accion:  Pass(P7, P) precondiciones:  [BallPocesion(P7), Player(P7), Player(P)]
#
# acciones q se pueden hacer []
# 8
# mira las acciones [Shoot(P6), Shoot(P4), Shoot(P3), Shoot(P5), Shoot(P1), Shoot(P9), Shoot(P2), Shoot(P8), Shoot(P10), Shoot(P), Shoot(P7), Pass(P6, P4), Pass(P6, P3), Pass(P6, P5), Pass(P6, P1), Pass(P6, P9), Pass(P6, P2), Pass(P6, P8), Pass(P6, P10), Pass(P6, P), Pass(P6, P7), Pass(P4, P6), Pass(P4, P3), Pass(P4, P5), Pass(P4, P1), Pass(P4, P9), Pass(P4, P2), Pass(P4, P8), Pass(P4, P10), Pass(P4, P), Pass(P4, P7), Pass(P3, P6), Pass(P3, P4), Pass(P3, P5), Pass(P3, P1), Pass(P3, P9), Pass(P3, P2), Pass(P3, P8), Pass(P3, P10), Pass(P3, P), Pass(P3, P7), Pass(P5, P6), Pass(P5, P4), Pass(P5, P3), Pass(P5, P1), Pass(P5, P9), Pass(P5, P2), Pass(P5, P8), Pass(P5, P10), Pass(P5, P), Pass(P5, P7), Pass(P1, P6), Pass(P1, P4), Pass(P1, P3), Pass(P1, P5), Pass(P1, P9), Pass(P1, P2), Pass(P1, P8), Pass(P1, P10), Pass(P1, P), Pass(P1, P7), Pass(P9, P6), Pass(P9, P4), Pass(P9, P3), Pass(P9, P5), Pass(P9, P1), Pass(P9, P2), Pass(P9, P8), Pass(P9, P10), Pass(P9, P), Pass(P9, P7), Pass(P2, P6), Pass(P2, P4), Pass(P2, P3), Pass(P2, P5), Pass(P2, P1), Pass(P2, P9), Pass(P2, P8), Pass(P2, P10), Pass(P2, P), Pass(P2, P7), Pass(P8, P6), Pass(P8, P4), Pass(P8, P3), Pass(P8, P5), Pass(P8, P1), Pass(P8, P9), Pass(P8, P2), Pass(P8, P10), Pass(P8, P), Pass(P8, P7), Pass(P10, P6), Pass(P10, P4), Pass(P10, P3), Pass(P10, P5), Pass(P10, P1), Pass(P10, P9), Pass(P10, P2), Pass(P10, P8), Pass(P10, P), Pass(P10, P7), Pass(P, P6), Pass(P, P4), Pass(P, P3), Pass(P, P5), Pass(P, P1), Pass(P, P9), Pass(P, P2), Pass(P, P8), Pass(P, P10), Pass(P, P7), Pass(P7, P6), Pass(P7, P4), Pass(P7, P3), Pass(P7, P5), Pass(P7, P1), Pass(P7, P9), Pass(P7, P2), Pass(P7, P8), Pass(P7, P10), Pass(P7, P)]
# precondiciones [Player(P), Player(P1), Player(P2), Player(P3), Player(P4), Player(P5), Player(P6), Player(P7), Player(P8), Player(P9), Player(P10), Player(P), Player(P1), Player(P2), Player(P3), Player(P4), Player(P5), Player(P6), Player(P7), Player(P8), Player(P9), Player(P10), NotBallPocesion(P), BallPocesion(P6)]
#
# accion:  Shoot(P6) precondiciones:  [BallPocesion(P6), Player(P6)]
#
# accion:  Shoot(P4) precondiciones:  [BallPocesion(P4), Player(P4)]
#
# accion:  Shoot(P3) precondiciones:  [BallPocesion(P3), Player(P3)]
#
# accion:  Shoot(P5) precondiciones:  [BallPocesion(P5), Player(P5)]
#
# accion:  Shoot(P1) precondiciones:  [BallPocesion(P1), Player(P1)]
#
# accion:  Shoot(P9) precondiciones:  [BallPocesion(P9), Player(P9)]
#
# accion:  Shoot(P2) precondiciones:  [BallPocesion(P2), Player(P2)]
#
# accion:  Shoot(P8) precondiciones:  [BallPocesion(P8), Player(P8)]
#
# accion:  Shoot(P10) precondiciones:  [BallPocesion(P10), Player(P10)]
#
# accion:  Shoot(P) precondiciones:  [BallPocesion(P), Player(P)]
#
# accion:  Shoot(P7) precondiciones:  [BallPocesion(P7), Player(P7)]
#
# accion:  Pass(P6, P4) precondiciones:  [BallPocesion(P6), Player(P6), Player(P4)]
#
# accion:  Pass(P6, P3) precondiciones:  [BallPocesion(P6), Player(P6), Player(P3)]
#
# accion:  Pass(P6, P5) precondiciones:  [BallPocesion(P6), Player(P6), Player(P5)]
#
# accion:  Pass(P6, P1) precondiciones:  [BallPocesion(P6), Player(P6), Player(P1)]
#
# accion:  Pass(P6, P9) precondiciones:  [BallPocesion(P6), Player(P6), Player(P9)]
#
# accion:  Pass(P6, P2) precondiciones:  [BallPocesion(P6), Player(P6), Player(P2)]
#
# accion:  Pass(P6, P8) precondiciones:  [BallPocesion(P6), Player(P6), Player(P8)]
#
# accion:  Pass(P6, P10) precondiciones:  [BallPocesion(P6), Player(P6), Player(P10)]
#
# accion:  Pass(P6, P) precondiciones:  [BallPocesion(P6), Player(P6), Player(P)]
#
# accion:  Pass(P6, P7) precondiciones:  [BallPocesion(P6), Player(P6), Player(P7)]
#
# accion:  Pass(P4, P6) precondiciones:  [BallPocesion(P4), Player(P4), Player(P6)]
#
# accion:  Pass(P4, P3) precondiciones:  [BallPocesion(P4), Player(P4), Player(P3)]
#
# accion:  Pass(P4, P5) precondiciones:  [BallPocesion(P4), Player(P4), Player(P5)]
#
# accion:  Pass(P4, P1) precondiciones:  [BallPocesion(P4), Player(P4), Player(P1)]
#
# accion:  Pass(P4, P9) precondiciones:  [BallPocesion(P4), Player(P4), Player(P9)]
#
# accion:  Pass(P4, P2) precondiciones:  [BallPocesion(P4), Player(P4), Player(P2)]
#
# accion:  Pass(P4, P8) precondiciones:  [BallPocesion(P4), Player(P4), Player(P8)]
#
# accion:  Pass(P4, P10) precondiciones:  [BallPocesion(P4), Player(P4), Player(P10)]
#
# accion:  Pass(P4, P) precondiciones:  [BallPocesion(P4), Player(P4), Player(P)]
#
# accion:  Pass(P4, P7) precondiciones:  [BallPocesion(P4), Player(P4), Player(P7)]
#
# accion:  Pass(P3, P6) precondiciones:  [BallPocesion(P3), Player(P3), Player(P6)]
#
# accion:  Pass(P3, P4) precondiciones:  [BallPocesion(P3), Player(P3), Player(P4)]
#
# accion:  Pass(P3, P5) precondiciones:  [BallPocesion(P3), Player(P3), Player(P5)]
#
# accion:  Pass(P3, P1) precondiciones:  [BallPocesion(P3), Player(P3), Player(P1)]
#
# accion:  Pass(P3, P9) precondiciones:  [BallPocesion(P3), Player(P3), Player(P9)]
#
# accion:  Pass(P3, P2) precondiciones:  [BallPocesion(P3), Player(P3), Player(P2)]
#
# accion:  Pass(P3, P8) precondiciones:  [BallPocesion(P3), Player(P3), Player(P8)]
#
# accion:  Pass(P3, P10) precondiciones:  [BallPocesion(P3), Player(P3), Player(P10)]
#
# accion:  Pass(P3, P) precondiciones:  [BallPocesion(P3), Player(P3), Player(P)]
#
# accion:  Pass(P3, P7) precondiciones:  [BallPocesion(P3), Player(P3), Player(P7)]
#
# accion:  Pass(P5, P6) precondiciones:  [BallPocesion(P5), Player(P5), Player(P6)]
#
# accion:  Pass(P5, P4) precondiciones:  [BallPocesion(P5), Player(P5), Player(P4)]
#
# accion:  Pass(P5, P3) precondiciones:  [BallPocesion(P5), Player(P5), Player(P3)]
#
# accion:  Pass(P5, P1) precondiciones:  [BallPocesion(P5), Player(P5), Player(P1)]
#
# accion:  Pass(P5, P9) precondiciones:  [BallPocesion(P5), Player(P5), Player(P9)]
#
# accion:  Pass(P5, P2) precondiciones:  [BallPocesion(P5), Player(P5), Player(P2)]
#
# accion:  Pass(P5, P8) precondiciones:  [BallPocesion(P5), Player(P5), Player(P8)]
#
# accion:  Pass(P5, P10) precondiciones:  [BallPocesion(P5), Player(P5), Player(P10)]
#
# accion:  Pass(P5, P) precondiciones:  [BallPocesion(P5), Player(P5), Player(P)]
#
# accion:  Pass(P5, P7) precondiciones:  [BallPocesion(P5), Player(P5), Player(P7)]
#
# accion:  Pass(P1, P6) precondiciones:  [BallPocesion(P1), Player(P1), Player(P6)]
#
# accion:  Pass(P1, P4) precondiciones:  [BallPocesion(P1), Player(P1), Player(P4)]
#
# accion:  Pass(P1, P3) precondiciones:  [BallPocesion(P1), Player(P1), Player(P3)]
#
# accion:  Pass(P1, P5) precondiciones:  [BallPocesion(P1), Player(P1), Player(P5)]
#
# accion:  Pass(P1, P9) precondiciones:  [BallPocesion(P1), Player(P1), Player(P9)]
#
# accion:  Pass(P1, P2) precondiciones:  [BallPocesion(P1), Player(P1), Player(P2)]
#
# accion:  Pass(P1, P8) precondiciones:  [BallPocesion(P1), Player(P1), Player(P8)]
#
# accion:  Pass(P1, P10) precondiciones:  [BallPocesion(P1), Player(P1), Player(P10)]
#
# accion:  Pass(P1, P) precondiciones:  [BallPocesion(P1), Player(P1), Player(P)]
#
# accion:  Pass(P1, P7) precondiciones:  [BallPocesion(P1), Player(P1), Player(P7)]
#
# accion:  Pass(P9, P6) precondiciones:  [BallPocesion(P9), Player(P9), Player(P6)]
#
# accion:  Pass(P9, P4) precondiciones:  [BallPocesion(P9), Player(P9), Player(P4)]
#
# accion:  Pass(P9, P3) precondiciones:  [BallPocesion(P9), Player(P9), Player(P3)]
#
# accion:  Pass(P9, P5) precondiciones:  [BallPocesion(P9), Player(P9), Player(P5)]
#
# accion:  Pass(P9, P1) precondiciones:  [BallPocesion(P9), Player(P9), Player(P1)]
#
# accion:  Pass(P9, P2) precondiciones:  [BallPocesion(P9), Player(P9), Player(P2)]
#
# accion:  Pass(P9, P8) precondiciones:  [BallPocesion(P9), Player(P9), Player(P8)]
#
# accion:  Pass(P9, P10) precondiciones:  [BallPocesion(P9), Player(P9), Player(P10)]
#
# accion:  Pass(P9, P) precondiciones:  [BallPocesion(P9), Player(P9), Player(P)]
#
# accion:  Pass(P9, P7) precondiciones:  [BallPocesion(P9), Player(P9), Player(P7)]
#
# accion:  Pass(P2, P6) precondiciones:  [BallPocesion(P2), Player(P2), Player(P6)]
#
# accion:  Pass(P2, P4) precondiciones:  [BallPocesion(P2), Player(P2), Player(P4)]
#
# accion:  Pass(P2, P3) precondiciones:  [BallPocesion(P2), Player(P2), Player(P3)]
#
# accion:  Pass(P2, P5) precondiciones:  [BallPocesion(P2), Player(P2), Player(P5)]
#
# accion:  Pass(P2, P1) precondiciones:  [BallPocesion(P2), Player(P2), Player(P1)]
#
# accion:  Pass(P2, P9) precondiciones:  [BallPocesion(P2), Player(P2), Player(P9)]
#
# accion:  Pass(P2, P8) precondiciones:  [BallPocesion(P2), Player(P2), Player(P8)]
#
# accion:  Pass(P2, P10) precondiciones:  [BallPocesion(P2), Player(P2), Player(P10)]
#
# accion:  Pass(P2, P) precondiciones:  [BallPocesion(P2), Player(P2), Player(P)]
#
# accion:  Pass(P2, P7) precondiciones:  [BallPocesion(P2), Player(P2), Player(P7)]
#
# accion:  Pass(P8, P6) precondiciones:  [BallPocesion(P8), Player(P8), Player(P6)]
#
# accion:  Pass(P8, P4) precondiciones:  [BallPocesion(P8), Player(P8), Player(P4)]
#
# accion:  Pass(P8, P3) precondiciones:  [BallPocesion(P8), Player(P8), Player(P3)]
#
# accion:  Pass(P8, P5) precondiciones:  [BallPocesion(P8), Player(P8), Player(P5)]
#
# accion:  Pass(P8, P1) precondiciones:  [BallPocesion(P8), Player(P8), Player(P1)]
#
# accion:  Pass(P8, P9) precondiciones:  [BallPocesion(P8), Player(P8), Player(P9)]
#
# accion:  Pass(P8, P2) precondiciones:  [BallPocesion(P8), Player(P8), Player(P2)]
#
# accion:  Pass(P8, P10) precondiciones:  [BallPocesion(P8), Player(P8), Player(P10)]
#
# accion:  Pass(P8, P) precondiciones:  [BallPocesion(P8), Player(P8), Player(P)]
#
# accion:  Pass(P8, P7) precondiciones:  [BallPocesion(P8), Player(P8), Player(P7)]
#
# accion:  Pass(P10, P6) precondiciones:  [BallPocesion(P10), Player(P10), Player(P6)]
#
# accion:  Pass(P10, P4) precondiciones:  [BallPocesion(P10), Player(P10), Player(P4)]
#
# accion:  Pass(P10, P3) precondiciones:  [BallPocesion(P10), Player(P10), Player(P3)]
#
# accion:  Pass(P10, P5) precondiciones:  [BallPocesion(P10), Player(P10), Player(P5)]
#
# accion:  Pass(P10, P1) precondiciones:  [BallPocesion(P10), Player(P10), Player(P1)]
#
# accion:  Pass(P10, P9) precondiciones:  [BallPocesion(P10), Player(P10), Player(P9)]
#
# accion:  Pass(P10, P2) precondiciones:  [BallPocesion(P10), Player(P10), Player(P2)]
#
# accion:  Pass(P10, P8) precondiciones:  [BallPocesion(P10), Player(P10), Player(P8)]
#
# accion:  Pass(P10, P) precondiciones:  [BallPocesion(P10), Player(P10), Player(P)]
#
# accion:  Pass(P10, P7) precondiciones:  [BallPocesion(P10), Player(P10), Player(P7)]
#
# accion:  Pass(P, P6) precondiciones:  [BallPocesion(P), Player(P), Player(P6)]
#
# accion:  Pass(P, P4) precondiciones:  [BallPocesion(P), Player(P), Player(P4)]
#
# accion:  Pass(P, P3) precondiciones:  [BallPocesion(P), Player(P), Player(P3)]
#
# accion:  Pass(P, P5) precondiciones:  [BallPocesion(P), Player(P), Player(P5)]
#
# accion:  Pass(P, P1) precondiciones:  [BallPocesion(P), Player(P), Player(P1)]
#
# accion:  Pass(P, P9) precondiciones:  [BallPocesion(P), Player(P), Player(P9)]
#
# accion:  Pass(P, P2) precondiciones:  [BallPocesion(P), Player(P), Player(P2)]
#
# accion:  Pass(P, P8) precondiciones:  [BallPocesion(P), Player(P), Player(P8)]
#
# accion:  Pass(P, P10) precondiciones:  [BallPocesion(P), Player(P), Player(P10)]
#
# accion:  Pass(P, P7) precondiciones:  [BallPocesion(P), Player(P), Player(P7)]
#
# accion:  Pass(P7, P6) precondiciones:  [BallPocesion(P7), Player(P7), Player(P6)]
#
# accion:  Pass(P7, P4) precondiciones:  [BallPocesion(P7), Player(P7), Player(P4)]
#
# accion:  Pass(P7, P3) precondiciones:  [BallPocesion(P7), Player(P7), Player(P3)]
#
# accion:  Pass(P7, P5) precondiciones:  [BallPocesion(P7), Player(P7), Player(P5)]
#
# accion:  Pass(P7, P1) precondiciones:  [BallPocesion(P7), Player(P7), Player(P1)]
#
# accion:  Pass(P7, P9) precondiciones:  [BallPocesion(P7), Player(P7), Player(P9)]
#
# accion:  Pass(P7, P2) precondiciones:  [BallPocesion(P7), Player(P7), Player(P2)]
#
# accion:  Pass(P7, P8) precondiciones:  [BallPocesion(P7), Player(P7), Player(P8)]
#
# accion:  Pass(P7, P10) precondiciones:  [BallPocesion(P7), Player(P7), Player(P10)]
#
# accion:  Pass(P7, P) precondiciones:  [BallPocesion(P7), Player(P7), Player(P)]
#
# acciones q se pueden hacer [Shoot(P6), Pass(P6, P4), Pass(P6, P3), Pass(P6, P5), Pass(P6, P1), Pass(P6, P9), Pass(P6, P2), Pass(P6, P8), Pass(P6, P10), Pass(P6, P), Pass(P6, P7)]
# 7
# mira las acciones [Shoot(P6), Shoot(P4), Shoot(P3), Shoot(P5), Shoot(P1), Shoot(P9), Shoot(P2), Shoot(P8), Shoot(P10), Shoot(P), Shoot(P7), Pass(P6, P4), Pass(P6, P3), Pass(P6, P5), Pass(P6, P1), Pass(P6, P9), Pass(P6, P2), Pass(P6, P8), Pass(P6, P10), Pass(P6, P), Pass(P6, P7), Pass(P4, P6), Pass(P4, P3), Pass(P4, P5), Pass(P4, P1), Pass(P4, P9), Pass(P4, P2), Pass(P4, P8), Pass(P4, P10), Pass(P4, P), Pass(P4, P7), Pass(P3, P6), Pass(P3, P4), Pass(P3, P5), Pass(P3, P1), Pass(P3, P9), Pass(P3, P2), Pass(P3, P8), Pass(P3, P10), Pass(P3, P), Pass(P3, P7), Pass(P5, P6), Pass(P5, P4), Pass(P5, P3), Pass(P5, P1), Pass(P5, P9), Pass(P5, P2), Pass(P5, P8), Pass(P5, P10), Pass(P5, P), Pass(P5, P7), Pass(P1, P6), Pass(P1, P4), Pass(P1, P3), Pass(P1, P5), Pass(P1, P9), Pass(P1, P2), Pass(P1, P8), Pass(P1, P10), Pass(P1, P), Pass(P1, P7), Pass(P9, P6), Pass(P9, P4), Pass(P9, P3), Pass(P9, P5), Pass(P9, P1), Pass(P9, P2), Pass(P9, P8), Pass(P9, P10), Pass(P9, P), Pass(P9, P7), Pass(P2, P6), Pass(P2, P4), Pass(P2, P3), Pass(P2, P5), Pass(P2, P1), Pass(P2, P9), Pass(P2, P8), Pass(P2, P10), Pass(P2, P), Pass(P2, P7), Pass(P8, P6), Pass(P8, P4), Pass(P8, P3), Pass(P8, P5), Pass(P8, P1), Pass(P8, P9), Pass(P8, P2), Pass(P8, P10), Pass(P8, P), Pass(P8, P7), Pass(P10, P6), Pass(P10, P4), Pass(P10, P3), Pass(P10, P5), Pass(P10, P1), Pass(P10, P9), Pass(P10, P2), Pass(P10, P8), Pass(P10, P), Pass(P10, P7), Pass(P, P6), Pass(P, P4), Pass(P, P3), Pass(P, P5), Pass(P, P1), Pass(P, P9), Pass(P, P2), Pass(P, P8), Pass(P, P10), Pass(P, P7), Pass(P7, P6), Pass(P7, P4), Pass(P7, P3), Pass(P7, P5), Pass(P7, P1), Pass(P7, P9), Pass(P7, P2), Pass(P7, P8), Pass(P7, P10), Pass(P7, P)]
# precondiciones [Player(P), Player(P1), Player(P2), Player(P3), Player(P4), Player(P5), Player(P6), Player(P7), Player(P8), Player(P9), Player(P10), Player(P), Player(P1), Player(P2), Player(P3), Player(P4), Player(P5), Player(P6), Player(P7), Player(P8), Player(P9), Player(P10), NotBallPocesion(P), BallPocesion(P4)]
#
# accion:  Shoot(P6) precondiciones:  [BallPocesion(P6), Player(P6)]
#
# accion:  Shoot(P4) precondiciones:  [BallPocesion(P4), Player(P4)]
#
# accion:  Shoot(P3) precondiciones:  [BallPocesion(P3), Player(P3)]
#
# accion:  Shoot(P5) precondiciones:  [BallPocesion(P5), Player(P5)]
#
# accion:  Shoot(P1) precondiciones:  [BallPocesion(P1), Player(P1)]
#
# accion:  Shoot(P9) precondiciones:  [BallPocesion(P9), Player(P9)]
#
# accion:  Shoot(P2) precondiciones:  [BallPocesion(P2), Player(P2)]
#
# accion:  Shoot(P8) precondiciones:  [BallPocesion(P8), Player(P8)]
#
# accion:  Shoot(P10) precondiciones:  [BallPocesion(P10), Player(P10)]
#
# accion:  Shoot(P) precondiciones:  [BallPocesion(P), Player(P)]
#
# accion:  Shoot(P7) precondiciones:  [BallPocesion(P7), Player(P7)]
#
# accion:  Pass(P6, P4) precondiciones:  [BallPocesion(P6), Player(P6), Player(P4)]
#
# accion:  Pass(P6, P3) precondiciones:  [BallPocesion(P6), Player(P6), Player(P3)]
#
# accion:  Pass(P6, P5) precondiciones:  [BallPocesion(P6), Player(P6), Player(P5)]
#
# accion:  Pass(P6, P1) precondiciones:  [BallPocesion(P6), Player(P6), Player(P1)]
#
# accion:  Pass(P6, P9) precondiciones:  [BallPocesion(P6), Player(P6), Player(P9)]
#
# accion:  Pass(P6, P2) precondiciones:  [BallPocesion(P6), Player(P6), Player(P2)]
#
# accion:  Pass(P6, P8) precondiciones:  [BallPocesion(P6), Player(P6), Player(P8)]
#
# accion:  Pass(P6, P10) precondiciones:  [BallPocesion(P6), Player(P6), Player(P10)]
#
# accion:  Pass(P6, P) precondiciones:  [BallPocesion(P6), Player(P6), Player(P)]
#
# accion:  Pass(P6, P7) precondiciones:  [BallPocesion(P6), Player(P6), Player(P7)]
#
# accion:  Pass(P4, P6) precondiciones:  [BallPocesion(P4), Player(P4), Player(P6)]
#
# accion:  Pass(P4, P3) precondiciones:  [BallPocesion(P4), Player(P4), Player(P3)]
#
# accion:  Pass(P4, P5) precondiciones:  [BallPocesion(P4), Player(P4), Player(P5)]
#
# accion:  Pass(P4, P1) precondiciones:  [BallPocesion(P4), Player(P4), Player(P1)]
#
# accion:  Pass(P4, P9) precondiciones:  [BallPocesion(P4), Player(P4), Player(P9)]
#
# accion:  Pass(P4, P2) precondiciones:  [BallPocesion(P4), Player(P4), Player(P2)]
#
# accion:  Pass(P4, P8) precondiciones:  [BallPocesion(P4), Player(P4), Player(P8)]
#
# accion:  Pass(P4, P10) precondiciones:  [BallPocesion(P4), Player(P4), Player(P10)]
#
# accion:  Pass(P4, P) precondiciones:  [BallPocesion(P4), Player(P4), Player(P)]
#
# accion:  Pass(P4, P7) precondiciones:  [BallPocesion(P4), Player(P4), Player(P7)]
#
# accion:  Pass(P3, P6) precondiciones:  [BallPocesion(P3), Player(P3), Player(P6)]
#
# accion:  Pass(P3, P4) precondiciones:  [BallPocesion(P3), Player(P3), Player(P4)]
#
# accion:  Pass(P3, P5) precondiciones:  [BallPocesion(P3), Player(P3), Player(P5)]
#
# accion:  Pass(P3, P1) precondiciones:  [BallPocesion(P3), Player(P3), Player(P1)]
#
# accion:  Pass(P3, P9) precondiciones:  [BallPocesion(P3), Player(P3), Player(P9)]
#
# accion:  Pass(P3, P2) precondiciones:  [BallPocesion(P3), Player(P3), Player(P2)]
#
# accion:  Pass(P3, P8) precondiciones:  [BallPocesion(P3), Player(P3), Player(P8)]
#
# accion:  Pass(P3, P10) precondiciones:  [BallPocesion(P3), Player(P3), Player(P10)]
#
# accion:  Pass(P3, P) precondiciones:  [BallPocesion(P3), Player(P3), Player(P)]
#
# accion:  Pass(P3, P7) precondiciones:  [BallPocesion(P3), Player(P3), Player(P7)]
#
# accion:  Pass(P5, P6) precondiciones:  [BallPocesion(P5), Player(P5), Player(P6)]
#
# accion:  Pass(P5, P4) precondiciones:  [BallPocesion(P5), Player(P5), Player(P4)]
#
# accion:  Pass(P5, P3) precondiciones:  [BallPocesion(P5), Player(P5), Player(P3)]
#
# accion:  Pass(P5, P1) precondiciones:  [BallPocesion(P5), Player(P5), Player(P1)]
#
# accion:  Pass(P5, P9) precondiciones:  [BallPocesion(P5), Player(P5), Player(P9)]
#
# accion:  Pass(P5, P2) precondiciones:  [BallPocesion(P5), Player(P5), Player(P2)]
#
# accion:  Pass(P5, P8) precondiciones:  [BallPocesion(P5), Player(P5), Player(P8)]
#
# accion:  Pass(P5, P10) precondiciones:  [BallPocesion(P5), Player(P5), Player(P10)]
#
# accion:  Pass(P5, P) precondiciones:  [BallPocesion(P5), Player(P5), Player(P)]
#
# accion:  Pass(P5, P7) precondiciones:  [BallPocesion(P5), Player(P5), Player(P7)]
#
# accion:  Pass(P1, P6) precondiciones:  [BallPocesion(P1), Player(P1), Player(P6)]
#
# accion:  Pass(P1, P4) precondiciones:  [BallPocesion(P1), Player(P1), Player(P4)]
#
# accion:  Pass(P1, P3) precondiciones:  [BallPocesion(P1), Player(P1), Player(P3)]
#
# accion:  Pass(P1, P5) precondiciones:  [BallPocesion(P1), Player(P1), Player(P5)]
#
# accion:  Pass(P1, P9) precondiciones:  [BallPocesion(P1), Player(P1), Player(P9)]
#
# accion:  Pass(P1, P2) precondiciones:  [BallPocesion(P1), Player(P1), Player(P2)]
#
# accion:  Pass(P1, P8) precondiciones:  [BallPocesion(P1), Player(P1), Player(P8)]
#
# accion:  Pass(P1, P10) precondiciones:  [BallPocesion(P1), Player(P1), Player(P10)]
#
# accion:  Pass(P1, P) precondiciones:  [BallPocesion(P1), Player(P1), Player(P)]
#
# accion:  Pass(P1, P7) precondiciones:  [BallPocesion(P1), Player(P1), Player(P7)]
#
# accion:  Pass(P9, P6) precondiciones:  [BallPocesion(P9), Player(P9), Player(P6)]
#
# accion:  Pass(P9, P4) precondiciones:  [BallPocesion(P9), Player(P9), Player(P4)]
#
# accion:  Pass(P9, P3) precondiciones:  [BallPocesion(P9), Player(P9), Player(P3)]
#
# accion:  Pass(P9, P5) precondiciones:  [BallPocesion(P9), Player(P9), Player(P5)]
#
# accion:  Pass(P9, P1) precondiciones:  [BallPocesion(P9), Player(P9), Player(P1)]
#
# accion:  Pass(P9, P2) precondiciones:  [BallPocesion(P9), Player(P9), Player(P2)]
#
# accion:  Pass(P9, P8) precondiciones:  [BallPocesion(P9), Player(P9), Player(P8)]
#
# accion:  Pass(P9, P10) precondiciones:  [BallPocesion(P9), Player(P9), Player(P10)]
#
# accion:  Pass(P9, P) precondiciones:  [BallPocesion(P9), Player(P9), Player(P)]
#
# accion:  Pass(P9, P7) precondiciones:  [BallPocesion(P9), Player(P9), Player(P7)]
#
# accion:  Pass(P2, P6) precondiciones:  [BallPocesion(P2), Player(P2), Player(P6)]
#
# accion:  Pass(P2, P4) precondiciones:  [BallPocesion(P2), Player(P2), Player(P4)]
#
# accion:  Pass(P2, P3) precondiciones:  [BallPocesion(P2), Player(P2), Player(P3)]
#
# accion:  Pass(P2, P5) precondiciones:  [BallPocesion(P2), Player(P2), Player(P5)]
#
# accion:  Pass(P2, P1) precondiciones:  [BallPocesion(P2), Player(P2), Player(P1)]
#
# accion:  Pass(P2, P9) precondiciones:  [BallPocesion(P2), Player(P2), Player(P9)]
#
# accion:  Pass(P2, P8) precondiciones:  [BallPocesion(P2), Player(P2), Player(P8)]
#
# accion:  Pass(P2, P10) precondiciones:  [BallPocesion(P2), Player(P2), Player(P10)]
#
# accion:  Pass(P2, P) precondiciones:  [BallPocesion(P2), Player(P2), Player(P)]
#
# accion:  Pass(P2, P7) precondiciones:  [BallPocesion(P2), Player(P2), Player(P7)]
#
# accion:  Pass(P8, P6) precondiciones:  [BallPocesion(P8), Player(P8), Player(P6)]
#
# accion:  Pass(P8, P4) precondiciones:  [BallPocesion(P8), Player(P8), Player(P4)]
#
# accion:  Pass(P8, P3) precondiciones:  [BallPocesion(P8), Player(P8), Player(P3)]
#
# accion:  Pass(P8, P5) precondiciones:  [BallPocesion(P8), Player(P8), Player(P5)]
#
# accion:  Pass(P8, P1) precondiciones:  [BallPocesion(P8), Player(P8), Player(P1)]
#
# accion:  Pass(P8, P9) precondiciones:  [BallPocesion(P8), Player(P8), Player(P9)]
#
# accion:  Pass(P8, P2) precondiciones:  [BallPocesion(P8), Player(P8), Player(P2)]
#
# accion:  Pass(P8, P10) precondiciones:  [BallPocesion(P8), Player(P8), Player(P10)]
#
# accion:  Pass(P8, P) precondiciones:  [BallPocesion(P8), Player(P8), Player(P)]
#
# accion:  Pass(P8, P7) precondiciones:  [BallPocesion(P8), Player(P8), Player(P7)]
#
# accion:  Pass(P10, P6) precondiciones:  [BallPocesion(P10), Player(P10), Player(P6)]
#
# accion:  Pass(P10, P4) precondiciones:  [BallPocesion(P10), Player(P10), Player(P4)]
#
# accion:  Pass(P10, P3) precondiciones:  [BallPocesion(P10), Player(P10), Player(P3)]
#
# accion:  Pass(P10, P5) precondiciones:  [BallPocesion(P10), Player(P10), Player(P5)]
#
# accion:  Pass(P10, P1) precondiciones:  [BallPocesion(P10), Player(P10), Player(P1)]
#
# accion:  Pass(P10, P9) precondiciones:  [BallPocesion(P10), Player(P10), Player(P9)]
#
# accion:  Pass(P10, P2) precondiciones:  [BallPocesion(P10), Player(P10), Player(P2)]
#
# accion:  Pass(P10, P8) precondiciones:  [BallPocesion(P10), Player(P10), Player(P8)]
#
# accion:  Pass(P10, P) precondiciones:  [BallPocesion(P10), Player(P10), Player(P)]
#
# accion:  Pass(P10, P7) precondiciones:  [BallPocesion(P10), Player(P10), Player(P7)]
#
# accion:  Pass(P, P6) precondiciones:  [BallPocesion(P), Player(P), Player(P6)]
#
# accion:  Pass(P, P4) precondiciones:  [BallPocesion(P), Player(P), Player(P4)]
#
# accion:  Pass(P, P3) precondiciones:  [BallPocesion(P), Player(P), Player(P3)]
#
# accion:  Pass(P, P5) precondiciones:  [BallPocesion(P), Player(P), Player(P5)]
#
# accion:  Pass(P, P1) precondiciones:  [BallPocesion(P), Player(P), Player(P1)]
#
# accion:  Pass(P, P9) precondiciones:  [BallPocesion(P), Player(P), Player(P9)]
#
# accion:  Pass(P, P2) precondiciones:  [BallPocesion(P), Player(P), Player(P2)]
#
# accion:  Pass(P, P8) precondiciones:  [BallPocesion(P), Player(P), Player(P8)]
#
# accion:  Pass(P, P10) precondiciones:  [BallPocesion(P), Player(P), Player(P10)]
#
# accion:  Pass(P, P7) precondiciones:  [BallPocesion(P), Player(P), Player(P7)]
#
# accion:  Pass(P7, P6) precondiciones:  [BallPocesion(P7), Player(P7), Player(P6)]
#
# accion:  Pass(P7, P4) precondiciones:  [BallPocesion(P7), Player(P7), Player(P4)]
#
# accion:  Pass(P7, P3) precondiciones:  [BallPocesion(P7), Player(P7), Player(P3)]
#
# accion:  Pass(P7, P5) precondiciones:  [BallPocesion(P7), Player(P7), Player(P5)]
#
# accion:  Pass(P7, P1) precondiciones:  [BallPocesion(P7), Player(P7), Player(P1)]
#
# ...
#
# accion:  Pass(P2, P7) precondiciones:  [BallPocesion(P2), Player(P2), Player(P7)]
#
# accion:  Pass(P8, P6) precondiciones:  [BallPocesion(P8), Player(P8), Player(P6)]
#
# accion:  Pass(P8, P4) precondiciones:  [BallPocesion(P8), Player(P8), Player(P4)]
#
# accion:  Pass(P8, P3) precondiciones:  [BallPocesion(P8), Player(P8), Player(P3)]
#
# accion:  Pass(P8, P5) precondiciones:  [BallPocesion(P8), Player(P8), Player(P5)]
#
# accion:  Pass(P8, P1) precondiciones:  [BallPocesion(P8), Player(P8), Player(P1)]
#
# accion:  Pass(P8, P9) precondiciones:  [BallPocesion(P8), Player(P8), Player(P9)]
#
# accion:  Pass(P8, P2) precondiciones:  [BallPocesion(P8), Player(P8), Player(P2)]
#
# accion:  Pass(P8, P10) precondiciones:  [BallPocesion(P8), Player(P8), Player(P10)]
#
# accion:  Pass(P8, P) precondiciones:  [BallPocesion(P8), Player(P8), Player(P)]
#
# accion:  Pass(P8, P7) precondiciones:  [BallPocesion(P8), Player(P8), Player(P7)]
#
# accion:  Pass(P10, P6) precondiciones:  [BallPocesion(P10), Player(P10), Player(P6)]
#
# accion:  Pass(P10, P4) precondiciones:  [BallPocesion(P10), Player(P10), Player(P4)]
#
# accion:  Pass(P10, P3) precondiciones:  [BallPocesion(P10), Player(P10), Player(P3)]
#
# accion:  Pass(P10, P5) precondiciones:  [BallPocesion(P10), Player(P10), Player(P5)]
#
# accion:  Pass(P10, P1) precondiciones:  [BallPocesion(P10), Player(P10), Player(P1)]
#
# accion:  Pass(P10, P9) precondiciones:  [BallPocesion(P10), Player(P10), Player(P9)]
#
# accion:  Pass(P10, P2) precondiciones:  [BallPocesion(P10), Player(P10), Player(P2)]
#
# accion:  Pass(P10, P8) precondiciones:  [BallPocesion(P10), Player(P10), Player(P8)]
#
# accion:  Pass(P10, P) precondiciones:  [BallPocesion(P10), Player(P10), Player(P)]
#
# accion:  Pass(P10, P7) precondiciones:  [BallPocesion(P10), Player(P10), Player(P7)]
#
# accion:  Pass(P, P6) precondiciones:  [BallPocesion(P), Player(P), Player(P6)]
#
# accion:  Pass(P, P4) precondiciones:  [BallPocesion(P), Player(P), Player(P4)]
#
# accion:  Pass(P, P3) precondiciones:  [BallPocesion(P), Player(P), Player(P3)]
#
# accion:  Pass(P, P5) precondiciones:  [BallPocesion(P), Player(P), Player(P5)]
#
# accion:  Pass(P, P1) precondiciones:  [BallPocesion(P), Player(P), Player(P1)]
#
# accion:  Pass(P, P9) precondiciones:  [BallPocesion(P), Player(P), Player(P9)]
#
# accion:  Pass(P, P2) precondiciones:  [BallPocesion(P), Player(P), Player(P2)]
#
# accion:  Pass(P, P8) precondiciones:  [BallPocesion(P), Player(P), Player(P8)]
#
# accion:  Pass(P, P10) precondiciones:  [BallPocesion(P), Player(P), Player(P10)]
#
# accion:  Pass(P, P7) precondiciones:  [BallPocesion(P), Player(P), Player(P7)]
#
# accion:  Pass(P7, P6) precondiciones:  [BallPocesion(P7), Player(P7), Player(P6)]
#
# accion:  Pass(P7, P4) precondiciones:  [BallPocesion(P7), Player(P7), Player(P4)]
#
# accion:  Pass(P7, P3) precondiciones:  [BallPocesion(P7), Player(P7), Player(P3)]
#
# accion:  Pass(P7, P5) precondiciones:  [BallPocesion(P7), Player(P7), Player(P5)]
#
# accion:  Pass(P7, P1) precondiciones:  [BallPocesion(P7), Player(P7), Player(P1)]
#
# accion:  Pass(P7, P9) precondiciones:  [BallPocesion(P7), Player(P7), Player(P9)]
#
# accion:  Pass(P7, P2) precondiciones:  [BallPocesion(P7), Player(P7), Player(P2)]
#
# accion:  Pass(P7, P8) precondiciones:  [BallPocesion(P7), Player(P7), Player(P8)]
#
# accion:  Pass(P7, P10) precondiciones:  [BallPocesion(P7), Player(P7), Player(P10)]
#
# accion:  Pass(P7, P) precondiciones:  [BallPocesion(P7), Player(P7), Player(P)]
#
# acciones q se pueden hacer [Shoot(P2), Pass(P2, P6), Pass(P2, P4), Pass(P2, P3), Pass(P2, P5), Pass(P2, P1), Pass(P2, P9), Pass(P2, P8), Pass(P2, P10), Pass(P2, P), Pass(P2, P7)]
# 1
# mira las acciones [Shoot(P6), Shoot(P4), Shoot(P3), Shoot(P5), Shoot(P1), Shoot(P9), Shoot(P2), Shoot(P8), Shoot(P10), Shoot(P), Shoot(P7), Pass(P6, P4), Pass(P6, P3), Pass(P6, P5), Pass(P6, P1), Pass(P6, P9), Pass(P6, P2), Pass(P6, P8), Pass(P6, P10), Pass(P6, P), Pass(P6, P7), Pass(P4, P6), Pass(P4, P3), Pass(P4, P5), Pass(P4, P1), Pass(P4, P9), Pass(P4, P2), Pass(P4, P8), Pass(P4, P10), Pass(P4, P), Pass(P4, P7), Pass(P3, P6), Pass(P3, P4), Pass(P3, P5), Pass(P3, P1), Pass(P3, P9), Pass(P3, P2), Pass(P3, P8), Pass(P3, P10), Pass(P3, P), Pass(P3, P7), Pass(P5, P6), Pass(P5, P4), Pass(P5, P3), Pass(P5, P1), Pass(P5, P9), Pass(P5, P2), Pass(P5, P8), Pass(P5, P10), Pass(P5, P), Pass(P5, P7), Pass(P1, P6), Pass(P1, P4), Pass(P1, P3), Pass(P1, P5), Pass(P1, P9), Pass(P1, P2), Pass(P1, P8), Pass(P1, P10), Pass(P1, P), Pass(P1, P7), Pass(P9, P6), Pass(P9, P4), Pass(P9, P3), Pass(P9, P5), Pass(P9, P1), Pass(P9, P2), Pass(P9, P8), Pass(P9, P10), Pass(P9, P), Pass(P9, P7), Pass(P2, P6), Pass(P2, P4), Pass(P2, P3), Pass(P2, P5), Pass(P2, P1), Pass(P2, P9), Pass(P2, P8), Pass(P2, P10), Pass(P2, P), Pass(P2, P7), Pass(P8, P6), Pass(P8, P4), Pass(P8, P3), Pass(P8, P5), Pass(P8, P1), Pass(P8, P9), Pass(P8, P2), Pass(P8, P10), Pass(P8, P), Pass(P8, P7), Pass(P10, P6), Pass(P10, P4), Pass(P10, P3), Pass(P10, P5), Pass(P10, P1), Pass(P10, P9), Pass(P10, P2), Pass(P10, P8), Pass(P10, P), Pass(P10, P7), Pass(P, P6), Pass(P, P4), Pass(P, P3), Pass(P, P5), Pass(P, P1), Pass(P, P9), Pass(P, P2), Pass(P, P8), Pass(P, P10), Pass(P, P7), Pass(P7, P6), Pass(P7, P4), Pass(P7, P3), Pass(P7, P5), Pass(P7, P1), Pass(P7, P9), Pass(P7, P2), Pass(P7, P8), Pass(P7, P10), Pass(P7, P)]
# precondiciones [Player(P), Player(P1), Player(P2), Player(P3), Player(P4), Player(P5), Player(P6), Player(P7), Player(P8), Player(P9), Player(P10), Player(P), Player(P1), Player(P2), Player(P3), Player(P4), Player(P5), Player(P6), Player(P7), Player(P8), Player(P9), Player(P10), NotBallPocesion(P), BallPocesion(P8)]
#
# accion:  Shoot(P6) precondiciones:  [BallPocesion(P6), Player(P6)]
#
# accion:  Shoot(P4) precondiciones:  [BallPocesion(P4), Player(P4)]
#
# accion:  Shoot(P3) precondiciones:  [BallPocesion(P3), Player(P3)]
#
# accion:  Shoot(P5) precondiciones:  [BallPocesion(P5), Player(P5)]
#
# accion:  Shoot(P1) precondiciones:  [BallPocesion(P1), Player(P1)]
#
# accion:  Shoot(P9) precondiciones:  [BallPocesion(P9), Player(P9)]
#
# accion:  Shoot(P2) precondiciones:  [BallPocesion(P2), Player(P2)]
#
# accion:  Shoot(P8) precondiciones:  [BallPocesion(P8), Player(P8)]
#
# accion:  Shoot(P10) precondiciones:  [BallPocesion(P10), Player(P10)]
#
# accion:  Shoot(P) precondiciones:  [BallPocesion(P), Player(P)]
#
# accion:  Shoot(P7) precondiciones:  [BallPocesion(P7), Player(P7)]
#
# accion:  Pass(P6, P4) precondiciones:  [BallPocesion(P6), Player(P6), Player(P4)]
#
# accion:  Pass(P6, P3) precondiciones:  [BallPocesion(P6), Player(P6), Player(P3)]
#
# accion:  Pass(P6, P5) precondiciones:  [BallPocesion(P6), Player(P6), Player(P5)]
#
# accion:  Pass(P6, P1) precondiciones:  [BallPocesion(P6), Player(P6), Player(P1)]
#
# accion:  Pass(P6, P9) precondiciones:  [BallPocesion(P6), Player(P6), Player(P9)]
#
# accion:  Pass(P6, P2) precondiciones:  [BallPocesion(P6), Player(P6), Player(P2)]
#
# accion:  Pass(P6, P8) precondiciones:  [BallPocesion(P6), Player(P6), Player(P8)]
#
# accion:  Pass(P6, P10) precondiciones:  [BallPocesion(P6), Player(P6), Player(P10)]
#
# accion:  Pass(P6, P) precondiciones:  [BallPocesion(P6), Player(P6), Player(P)]
#
# accion:  Pass(P6, P7) precondiciones:  [BallPocesion(P6), Player(P6), Player(P7)]
#
# accion:  Pass(P4, P6) precondiciones:  [BallPocesion(P4), Player(P4), Player(P6)]
#
# accion:  Pass(P4, P3) precondiciones:  [BallPocesion(P4), Player(P4), Player(P3)]
#
# accion:  Pass(P4, P5) precondiciones:  [BallPocesion(P4), Player(P4), Player(P5)]
#
# accion:  Pass(P4, P1) precondiciones:  [BallPocesion(P4), Player(P4), Player(P1)]
#
# accion:  Pass(P4, P9) precondiciones:  [BallPocesion(P4), Player(P4), Player(P9)]
#
# accion:  Pass(P4, P2) precondiciones:  [BallPocesion(P4), Player(P4), Player(P2)]
#
# accion:  Pass(P4, P8) precondiciones:  [BallPocesion(P4), Player(P4), Player(P8)]
#
# accion:  Pass(P4, P10) precondiciones:  [BallPocesion(P4), Player(P4), Player(P10)]
#
# accion:  Pass(P4, P) precondiciones:  [BallPocesion(P4), Player(P4), Player(P)]
#
# accion:  Pass(P4, P7) precondiciones:  [BallPocesion(P4), Player(P4), Player(P7)]
#
# accion:  Pass(P3, P6) precondiciones:  [BallPocesion(P3), Player(P3), Player(P6)]
#
# accion:  Pass(P3, P4) precondiciones:  [BallPocesion(P3), Player(P3), Player(P4)]
#
# accion:  Pass(P3, P5) precondiciones:  [BallPocesion(P3), Player(P3), Player(P5)]
#
# accion:  Pass(P3, P1) precondiciones:  [BallPocesion(P3), Player(P3), Player(P1)]
#
# accion:  Pass(P3, P9) precondiciones:  [BallPocesion(P3), Player(P3), Player(P9)]
#
# accion:  Pass(P3, P2) precondiciones:  [BallPocesion(P3), Player(P3), Player(P2)]
#
# accion:  Pass(P3, P8) precondiciones:  [BallPocesion(P3), Player(P3), Player(P8)]
#
# accion:  Pass(P3, P10) precondiciones:  [BallPocesion(P3), Player(P3), Player(P10)]
#
# accion:  Pass(P3, P) precondiciones:  [BallPocesion(P3), Player(P3), Player(P)]
#
# accion:  Pass(P3, P7) precondiciones:  [BallPocesion(P3), Player(P3), Player(P7)]
#
# accion:  Pass(P5, P6) precondiciones:  [BallPocesion(P5), Player(P5), Player(P6)]
#
# accion:  Pass(P5, P4) precondiciones:  [BallPocesion(P5), Player(P5), Player(P4)]
#
# accion:  Pass(P5, P3) precondiciones:  [BallPocesion(P5), Player(P5), Player(P3)]
#
# accion:  Pass(P5, P1) precondiciones:  [BallPocesion(P5), Player(P5), Player(P1)]
#
# accion:  Pass(P5, P9) precondiciones:  [BallPocesion(P5), Player(P5), Player(P9)]
#
# accion:  Pass(P5, P2) precondiciones:  [BallPocesion(P5), Player(P5), Player(P2)]
#
# accion:  Pass(P5, P8) precondiciones:  [BallPocesion(P5), Player(P5), Player(P8)]
#
# accion:  Pass(P5, P10) precondiciones:  [BallPocesion(P5), Player(P5), Player(P10)]
#
# accion:  Pass(P5, P) precondiciones:  [BallPocesion(P5), Player(P5), Player(P)]
#
# accion:  Pass(P5, P7) precondiciones:  [BallPocesion(P5), Player(P5), Player(P7)]
#
# accion:  Pass(P1, P6) precondiciones:  [BallPocesion(P1), Player(P1), Player(P6)]
#
# accion:  Pass(P1, P4) precondiciones:  [BallPocesion(P1), Player(P1), Player(P4)]
#
# accion:  Pass(P1, P3) precondiciones:  [BallPocesion(P1), Player(P1), Player(P3)]
#
# accion:  Pass(P1, P5) precondiciones:  [BallPocesion(P1), Player(P1), Player(P5)]
#
# accion:  Pass(P1, P9) precondiciones:  [BallPocesion(P1), Player(P1), Player(P9)]
#
# accion:  Pass(P1, P2) precondiciones:  [BallPocesion(P1), Player(P1), Player(P2)]
#
# accion:  Pass(P1, P8) precondiciones:  [BallPocesion(P1), Player(P1), Player(P8)]
#
# accion:  Pass(P1, P10) precondiciones:  [BallPocesion(P1), Player(P1), Player(P10)]
#
# accion:  Pass(P1, P) precondiciones:  [BallPocesion(P1), Player(P1), Player(P)]
#
# accion:  Pass(P1, P7) precondiciones:  [BallPocesion(P1), Player(P1), Player(P7)]
#
# accion:  Pass(P9, P6) precondiciones:  [BallPocesion(P9), Player(P9), Player(P6)]
#
# accion:  Pass(P9, P4) precondiciones:  [BallPocesion(P9), Player(P9), Player(P4)]
#
# accion:  Pass(P9, P3) precondiciones:  [BallPocesion(P9), Player(P9), Player(P3)]
#
# accion:  Pass(P9, P5) precondiciones:  [BallPocesion(P9), Player(P9), Player(P5)]
#
# accion:  Pass(P9, P1) precondiciones:  [BallPocesion(P9), Player(P9), Player(P1)]
#
# accion:  Pass(P9, P2) precondiciones:  [BallPocesion(P9), Player(P9), Player(P2)]
#
# accion:  Pass(P9, P8) precondiciones:  [BallPocesion(P9), Player(P9), Player(P8)]
#
# accion:  Pass(P9, P10) precondiciones:  [BallPocesion(P9), Player(P9), Player(P10)]
#
# accion:  Pass(P9, P) precondiciones:  [BallPocesion(P9), Player(P9), Player(P)]
#
# accion:  Pass(P9, P7) precondiciones:  [BallPocesion(P9), Player(P9), Player(P7)]
#
# accion:  Pass(P2, P6) precondiciones:  [BallPocesion(P2), Player(P2), Player(P6)]
#
# accion:  Pass(P2, P4) precondiciones:  [BallPocesion(P2), Player(P2), Player(P4)]
#
# accion:  Pass(P2, P3) precondiciones:  [BallPocesion(P2), Player(P2), Player(P3)]
#
# accion:  Pass(P2, P5) precondiciones:  [BallPocesion(P2), Player(P2), Player(P5)]
#
# accion:  Pass(P2, P1) precondiciones:  [BallPocesion(P2), Player(P2), Player(P1)]
#
# accion:  Pass(P2, P9) precondiciones:  [BallPocesion(P2), Player(P2), Player(P9)]
#
# accion:  Pass(P2, P8) precondiciones:  [BallPocesion(P2), Player(P2), Player(P8)]
#
# accion:  Pass(P2, P10) precondiciones:  [BallPocesion(P2), Player(P2), Player(P10)]
#
# accion:  Pass(P2, P) precondiciones:  [BallPocesion(P2), Player(P2), Player(P)]
#
# accion:  Pass(P2, P7) precondiciones:  [BallPocesion(P2), Player(P2), Player(P7)]
#
# accion:  Pass(P8, P6) precondiciones:  [BallPocesion(P8), Player(P8), Player(P6)]
#
# accion:  Pass(P8, P4) precondiciones:  [BallPocesion(P8), Player(P8), Player(P4)]
#
# accion:  Pass(P8, P3) precondiciones:  [BallPocesion(P8), Player(P8), Player(P3)]
#
# accion:  Pass(P8, P5) precondiciones:  [BallPocesion(P8), Player(P8), Player(P5)]
#
# accion:  Pass(P8, P1) precondiciones:  [BallPocesion(P8), Player(P8), Player(P1)]
#
# accion:  Pass(P8, P9) precondiciones:  [BallPocesion(P8), Player(P8), Player(P9)]
#
# accion:  Pass(P8, P2) precondiciones:  [BallPocesion(P8), Player(P8), Player(P2)]
#
# accion:  Pass(P8, P10) precondiciones:  [BallPocesion(P8), Player(P8), Player(P10)]
#
# accion:  Pass(P8, P) precondiciones:  [BallPocesion(P8), Player(P8), Player(P)]
#
# accion:  Pass(P8, P7) precondiciones:  [BallPocesion(P8), Player(P8), Player(P7)]
#
# accion:  Pass(P10, P6) precondiciones:  [BallPocesion(P10), Player(P10), Player(P6)]
#
# accion:  Pass(P10, P4) precondiciones:  [BallPocesion(P10), Player(P10), Player(P4)]
#
# accion:  Pass(P10, P3) precondiciones:  [BallPocesion(P10), Player(P10), Player(P3)]
#
# accion:  Pass(P10, P5) precondiciones:  [BallPocesion(P10), Player(P10), Player(P5)]
#
# accion:  Pass(P10, P1) precondiciones:  [BallPocesion(P10), Player(P10), Player(P1)]
#
# accion:  Pass(P10, P9) precondiciones:  [BallPocesion(P10), Player(P10), Player(P9)]
#
# accion:  Pass(P10, P2) precondiciones:  [BallPocesion(P10), Player(P10), Player(P2)]
#
# accion:  Pass(P10, P8) precondiciones:  [BallPocesion(P10), Player(P10), Player(P8)]
#
# accion:  Pass(P10, P) precondiciones:  [BallPocesion(P10), Player(P10), Player(P)]
#
# accion:  Pass(P10, P7) precondiciones:  [BallPocesion(P10), Player(P10), Player(P7)]
#
# accion:  Pass(P, P6) precondiciones:  [BallPocesion(P), Player(P), Player(P6)]
#
# accion:  Pass(P, P4) precondiciones:  [BallPocesion(P), Player(P), Player(P4)]
#
# accion:  Pass(P, P3) precondiciones:  [BallPocesion(P), Player(P), Player(P3)]
#
# accion:  Pass(P, P5) precondiciones:  [BallPocesion(P), Player(P), Player(P5)]
#
# accion:  Pass(P, P1) precondiciones:  [BallPocesion(P), Player(P), Player(P1)]
#
# accion:  Pass(P, P9) precondiciones:  [BallPocesion(P), Player(P), Player(P9)]
#
# accion:  Pass(P, P2) precondiciones:  [BallPocesion(P), Player(P), Player(P2)]
#
# accion:  Pass(P, P8) precondiciones:  [BallPocesion(P), Player(P), Player(P8)]
#
# accion:  Pass(P, P10) precondiciones:  [BallPocesion(P), Player(P), Player(P10)]
#
# accion:  Pass(P, P7) precondiciones:  [BallPocesion(P), Player(P), Player(P7)]
#
# accion:  Pass(P7, P6) precondiciones:  [BallPocesion(P7), Player(P7), Player(P6)]
#
# accion:  Pass(P7, P4) precondiciones:  [BallPocesion(P7), Player(P7), Player(P4)]
#
# accion:  Pass(P7, P3) precondiciones:  [BallPocesion(P7), Player(P7), Player(P3)]
#
# accion:  Pass(P7, P5) precondiciones:  [BallPocesion(P7), Player(P7), Player(P5)]
#
# accion:  Pass(P7, P1) precondiciones:  [BallPocesion(P7), Player(P7), Player(P1)]
#
# accion:  Pass(P7, P9) precondiciones:  [BallPocesion(P7), Player(P7), Player(P9)]
#
# accion:  Pass(P7, P2) precondiciones:  [BallPocesion(P7), Player(P7), Player(P2)]
#
# accion:  Pass(P7, P8) precondiciones:  [BallPocesion(P7), Player(P7), Player(P8)]
#
# accion:  Pass(P7, P10) precondiciones:  [BallPocesion(P7), Player(P7), Player(P10)]
#
# accion:  Pass(P7, P) precondiciones:  [BallPocesion(P7), Player(P7), Player(P)]
#
# acciones q se pueden hacer [Shoot(P8), Pass(P8, P6), Pass(P8, P4), Pass(P8, P3), Pass(P8, P5), Pass(P8, P1), Pass(P8, P9), Pass(P8, P2), Pass(P8, P10), Pass(P8, P), Pass(P8, P7)]
# 0
# [<Node (Player(P) & Player(P1) & Player(P2) & Player(P3) & Player(P4) & Player(P5) & Player(P6) & Player(P7) & Player(P8) & Player(P9) & Player(P10) & Player(P) & Player(P1) & Player(P2) & Player(P3) & Player(P4) & Player(P5) & Player(P6) & Player(P7) & Player(P8) & Player(P9) & Player(P10) & BallInGoal & NotBallPocesion(P))>]

# %%
variables
# Out:
# {'P': <player.Player at 0x7f76622d9cc0>,
#  'P1': <player.Player at 0x7f76622dace0>,
#  'P2': <player.Player at 0x7f76622dba60>,
#  'P3': <player.Player at 0x7f767c1c3b50>,
#  'P4': <player.Player at 0x7f767c1c3f40>,
#  'P5': <player.Player at 0x7f767c1c26e0>,
#  'P6': <player.Player at 0x7f7662c381f0>,
#  'P7': <player.Player at 0x7f7662c38250>,
#  'P8': <player.Player at 0x7f7662c38280>,
#  'P9': <player.Player at 0x7f7662c38130>,
#  'P10': <player.Player at 0x7f76622d9240>}

# %%
solution, prec = sol.solution(variables)
prec
# Out:
# 0.243375

# %%
message = f'{variables[str(solution.args[0])].name} {solution.name}'
message
# Out:
# 'Richarlison Shoot'

# %%
variables[str(solution.args[0])].position.row
# Out:
# 2

# %%
team.players[2].name
# Out:
# 'Richarlison'

# %%
t1 = Team('brazil', field.field)
t1.players
# Out:
# [<player.Player at 0x7f76622d9ba0>,
#  <player.Player at 0x7f76622d91e0>,
#  <player.Player at 0x7f76622da8f0>,
#  <player.Player at 0x7f76622d9e70>,
#  <player.Player at 0x7f76622d94e0>,
#  <player.Player at 0x7f76622da8c0>,
#  <player.Player at 0x7f76622da650>,
#  <player.Player at 0x7f76622da680>,
#  <player.Player at 0x7f76622d9570>,
#  <player.Player at 0x7f76622d9c00>,
#  <player.Player at 0x7f76622d9060>]
