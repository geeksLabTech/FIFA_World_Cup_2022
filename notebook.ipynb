# %%
from tournament import Tournament

# %%
t = Tournament()
t.run()
# Out:
# Starting tournament
# Start GameStart Game
#
# Start GameStart GameStart GameStart GameStart Game
# Start Game
#
#
#
#
# Draw mexico poland [4, 4]
# Start Game
# Team usa win [4, 2]
# Start Game
# Draw denmark tunisia [6, 6]
# Start Game
# Team senegal win [7, 3]
# Start Game
# Team cameroon win [3, 7]
# Start Game
# Team canada win [3, 7]
# Start Game
# Team uruguay winTeam germany win  [7, 3]
# [7, 3]
# Start Game
# Start Game
# Team poland win [7, 12]
# Start Game
# Team iran win [16, 13]
# Start Game
# Team netherlands win [8, 15]
# Start Game
# Team costa-rica win [11, 6]
# Start Game
# Team australia win [8, 7]
# Start Game
# Draw ghana south-korea [7, 7]
# Start Game
# Team canada win [6, 7]
# Start Game
# Team serbia win [13, 6]
# Start Game
# Team saudi-arabia win [14, 10]
# Start Game
# Team usa win [9, 10]
# Start Game
# Team senegal win [8, 11]
# Start Game
# Team costa-rica win [9, 6]
# Start Game
# Team australia win [12, 5]
# Start Game
# Team belgium win [7, 12]
# ...
